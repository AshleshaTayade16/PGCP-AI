# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer, make_column_selector

# %%
train=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Irrigation\\train.csv",index_col=0)
train
# Out:
#        Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# id
# 0          Loamy     4.92          32.58            1.01
# 1           Clay     7.08          56.61            0.44
# 2           Clay     5.69          27.71            0.81
# 3          Sandy     5.65          13.32            1.33
# 4           Clay     7.96          59.14            0.38
# ...          ...      ...            ...             ...
# 629995      Clay     6.54          13.45            1.15
# 629996      Clay     7.03          54.49            0.96
# 629997      Clay     6.52          11.98            0.93
# 629998      Clay     5.93          42.86            0.33
# 629999     Loamy     7.02          35.36            1.19
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# id
# 0                          3.05          15.01     50.61       725.99
# 1                          2.00          22.92     67.86       985.66
# ...

# %%
test=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Irrigation\\test.csv",index_col=0)
test
# Out:
#        Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# id
# 630000      Silt     6.36          26.19            0.59
# 630001      Clay     5.87           9.88            1.18
# 630002     Sandy     6.22          26.55            0.96
# 630003      Clay     7.68          53.58            0.83
# 630004     Loamy     5.23          59.02            0.54
# ...          ...      ...            ...             ...
# 899995     Sandy     5.63          51.90            0.68
# 899996     Loamy     7.84          45.16            0.85
# 899997     Loamy     7.83          11.02            1.56
# 899998      Silt     7.12          10.18            1.32
# 899999      Clay     6.61          24.96            1.41
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# id
# 630000                     2.81          17.83     30.24      1533.38
# 630001                     3.26          21.18     78.07       576.05
# ...

# %%
infile=open('bm_rf_pkl','rb')
objLoad=pickle.load(infile)
infile.close()

# %%
y=train['Irrigation_Need']
X=train.drop('Irrigation_Need',axis=1)

# %%
scaler=StandardScaler().set_output(transform='pandas')
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=26,stratify=y)
ohe=OneHotEncoder(sparse_output=False,drop="first").set_output(transform="pandas")
trns=ColumnTransformer(transformers=[("OHE",ohe, make_column_selector
                                        (dtype_include=object))],remainder="passthrough",verbose_feature_names_out=False).set_output(transform="pandas")
X_trn_ohe=trns.fit_transform(X_train)
X_tst_ohe=trns.transform(X_test)

# %%
procomp=PCA()
xgb=XGBClassifier(random_state=26)
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=26)
pipe=Pipeline([('TRNF',trns),('XGB',xgb)])
pipe.get_params()
params = {
    'XGB__max_depth': [3, 5, 7],
    'XGB__learning_rate': [0.1, 0.2, 0.3, 0.4], # <--- Double underscore
    'XGB__n_estimators': [20, 30, 50]         # <--- Double underscore
}
gcv=GridSearchCV(estimator=pipe,param_grid=params,cv=kfold,scoring='accuracy',verbose=3)
gcv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=20;, score=nan total time=   1.1s
# [CV 2/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=20;, score=nan total time=   1.2s
# [CV 3/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=20;, score=nan total time=   1.2s
# [CV 4/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=20;, score=nan total time=   1.2s
# [CV 5/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=20;, score=nan total time=   1.2s
# [CV 1/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=30;, score=nan total time=   1.2s
# [CV 2/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=30;, score=nan total time=   1.2s
# [CV 3/5] END XGB__learning_rate=0.1, XGB__max_depth=3, XGB__n_estimators=30;, score=nan total time=   1.2s
# ...

# %%
print("Best Params:", gcv.best_params_)
print("Best Score:", gcv.best_score_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print("Best Params:", gcv.best_params_)
#       2 print("Best Score:", gcv.best_score_)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
bm=gcv.best_estimator_
y_pred=le.inverse_transform(bm.predict(test))

# %%
submit=pd.read_csv("sample_submission.csv")
