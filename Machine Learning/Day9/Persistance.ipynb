# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
cancer=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Wisconsin\\BreastCancer.csv",index_col=0)
cancer
# Out:
#           Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# Code
# 61634         5             4              3        1       2      2
# 63375         9             1              2        6       4     10
# 76389        10             4              7        2       2      8
# 95719         6            10             10       10       8     10
# 128059        1             1              1        1       2      5
# ...         ...           ...            ...      ...     ...    ...
# 1369821      10            10             10       10       5     10
# 1371026       5            10             10       10       4     10
# 1371920       5             1              1        1       2      1
# 8233704       4             1              1        1       1      1
# 13454352      1             1              3        1       2      1
#
#           BChromatin  NoemN  Mitoses      Class
# Code
# 61634              2      3        1     Benign
# 63375              7      7        2  Malignant
# 76389              6      1        1  Malignant
# 95719              7     10        7  Malignant
# 128059             5      1        1     Benign
# ...              ...    ...      ...        ...
# 1369821           10     10        7  Malignant
# 1371026            5      6        3  Malignant
# 1371920            3      2        1     Benign
# 8233704            2      1        1     Benign
# 13454352           2      1        1     Benign
#
# [699 rows x 10 columns]

# %%
X = cancer.drop('Class',axis=1)
y = cancer['Class']

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
scores = cross_val_score(rf, X, y, cv=cv, scoring='accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 scores = cross_val_score(rf, X, y, cv=cv, scoring='accuracy')
#
# NameError: name 'rf' is not defined

# %%
bm = RandomForestClassifier(
    n_estimators=100,        # number of trees
    max_depth=None,          # let trees expand fully
    random_state=42
)

# %%
scores = cross_val_score(bm, X, y, cv=cv, scoring='accuracy')
bm.fit(X,y)
print("Cross-validation scores:", scores)
print("Mean CV accuracy:", scores.mean())
# Out:
# Cross-validation scores: [0.96428571 0.95714286 0.95714286 0.97857143 0.98561151]
# Mean CV accuracy: 0.9685508735868448

# %%
import pickle
pkfile=open('bm_rf.pkl','wb')
pickle.dump(bm,pkfile)
pkfile.close()
