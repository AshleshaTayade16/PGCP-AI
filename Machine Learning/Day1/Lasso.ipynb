# %%
import numpy as np
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
os.chdir("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Datasets")

# %%
boston=pd.read_csv("Boston.csv")
X=boston.drop("medv",axis=1)
y=boston["medv"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=26)

# %%
lasso=Lasso()
lasso.fit(X_train,y_train)
y_pred=lasso.predict(X_test)
print(lasso.coef_)
print("R2=",r2_score(y_test,y_pred))
# Out:
# [-0.0834926   0.03083338  0.          0.          0.          1.03852946
#   0.02152878 -0.61999701  0.21847777 -0.01223755 -0.72275687  0.00852792
#  -0.77152776]
# R2= 0.7088633322868478

# %%
alphas=np.linspace(0.001,5)
scores=[]
for a in alphas:
    lasso=Lasso(alpha=a)
    lasso.fit(X_train,y_train)
    y_pred=lasso.predict(X_test)
    scores.append([a,r2_score(y_test,y_pred)])
df_scores=pd.DataFrame(scores,columns=["alpha","score"])
df_scores.sort_values(by="score",ascending=False)
# Out:
#        alpha     score
# 0   0.001000  0.746896
# 3   0.307061  0.744541
# 2   0.205041  0.743934
# 4   0.409082  0.743702
# 1   0.103020  0.741792
# 5   0.511102  0.741391
# 6   0.613122  0.737498
# 7   0.715143  0.732078
# 8   0.817163  0.725132
# 9   0.919184  0.716659
# 10  1.021204  0.706660
# 11  1.123224  0.695134
# 12  1.225245  0.682082
# 13  1.327265  0.670064
# 14  1.429286  0.664762
# 15  1.531306  0.659030
# 16  1.633327  0.652862
# 17  1.735347  0.646254
# 18  1.837367  0.639214
# 19  1.939388  0.632215
# 20  2.041408  0.628628
# 21  2.143429  0.624928
# 22  2.245449  0.621008
# 23  2.347469  0.616914
# 24  2.449490  0.612651
# 25  2.551510  0.608222
# 26  2.653531  0.603625
# 27  2.755551  0.598851
# 28  2.857571  0.593916
# 29  2.959592  0.588815
# 30  3.061612  0.583536
# 31  3.163633  0.578892
# 32  3.265653  0.575231
# 33  3.367673  0.571458
# 34  3.469694  0.567574
# 35  3.571714  0.566044
# 36  3.673735  0.565431
# 37  3.775755  0.564801
# 38  3.877776  0.564153
# 39  3.979796  0.563489
# 40  4.081816  0.562810
# 41  4.183837  0.562115
# 42  4.285857  0.561406
# 43  4.387878  0.560682
# 44  4.489898  0.559945
# 45  4.591918  0.559194
# 46  4.693939  0.558429
# 47  4.795959  0.557651
# 48  4.897980  0.556858
# 49  5.000000  0.556052
