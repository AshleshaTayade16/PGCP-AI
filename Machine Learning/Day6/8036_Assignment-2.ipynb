# %% [markdown]
# #Assignment-2
# #Name-Ashlesha Tayade                                 Name-Ruchika Gaikwad
# #PRN-260240128008                                     PRN-260240128036

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import  ColumnTransformer, make_column_selector
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import log_loss
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %%
# train = pd.read_csv('C:/Users/PGCP-AI/Downloads/IrrigationKaggle/train.csv')
train = pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Day6\\playground-series-s6e4 (1)\\train.csv")
train
# Out:
#             id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0            0     Loamy     4.92          32.58            1.01
# 1            1      Clay     7.08          56.61            0.44
# 2            2      Clay     5.69          27.71            0.81
# 3            3     Sandy     5.65          13.32            1.33
# 4            4      Clay     7.96          59.14            0.38
# ...        ...       ...      ...            ...             ...
# 629995  629995      Clay     6.54          13.45            1.15
# 629996  629996      Clay     7.03          54.49            0.96
# 629997  629997      Clay     6.52          11.98            0.93
# 629998  629998      Clay     5.93          42.86            0.33
# 629999  629999     Loamy     7.02          35.36            1.19
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                          3.05          15.01     50.61       725.99
# 1                          2.00          22.92     67.86       985.66
# 2                          2.83          26.97     92.22      2201.70
# 3                          0.87          13.32     61.57      1357.33
# 4                          0.96          20.22     91.11      1538.20
# ...                         ...            ...       ...          ...
# 629995                     1.86          26.65     26.86      1041.33
# 629996                     2.35          36.99     88.00      1419.57
# 629997                     0.38          37.82     70.98        88.45
# 629998                     3.39          34.99     94.58      2433.92
# 629999                     0.46          26.92     64.33      1269.55
#
#         Sunlight_Hours  ...  Crop_Type Crop_Growth_Stage  Season  \
# 0                 5.90  ...  Sugarcane            Sowing    Zaid
# 1                 6.98  ...      Wheat        Vegetative  Kharif
# 2                 6.05  ...       Rice        Vegetative  Kharif
# 3                 9.12  ...      Wheat         Flowering  Kharif
# 4                 6.95  ...      Wheat            Sowing    Rabi
# ...                ...  ...        ...               ...     ...
# 629995           10.62  ...       Rice            Sowing  Kharif
# 629996            9.93  ...  Sugarcane        Vegetative  Kharif
# 629997            8.19  ...     Potato        Vegetative    Zaid
# 629998            9.88  ...  Sugarcane        Vegetative    Zaid
# 629999            7.91  ...      Maize           Harvest  Kharif
#
#        Irrigation_Type Water_Source Field_Area_hectare  Mulching_Used  \
# 0                 Drip    Rainwater               0.82             No
# 1              Rainfed        River               5.27            Yes
# 2            Sprinkler    Reservoir               8.24            Yes
# 3                Canal        River               8.32            Yes
# 4                Canal        River               7.37             No
# ...                ...          ...                ...            ...
# 629995       Sprinkler        River               4.35             No
# 629996            Drip  Groundwater              12.97            Yes
# 629997           Canal    Reservoir              13.58            Yes
# 629998       Sprinkler  Groundwater               0.79            Yes
# 629999            Drip    Reservoir               3.80             No
#
#        Previous_Irrigation_mm   Region Irrigation_Need
# 0                      112.16     East             Low
# 1                       47.16    South             Low
# 2                      110.38    North             Low
# 3                       53.85    South          Medium
# 4                       93.19    South             Low
# ...                       ...      ...             ...
# 629995                 118.36    South          Medium
# 629996                  40.75  Central          Medium
# 629997                   2.62    South            High
# 629998                  90.00     East             Low
# 629999                 112.93     West             Low
#
# [630000 rows x 21 columns]

# %%
test = pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Day6\\playground-series-s6e4 (1)\\test.csv")
test.head()
# Out:
#        id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0  630000      Silt     6.36          26.19            0.59
# 1  630001      Clay     5.87           9.88            1.18
# 2  630002     Sandy     6.22          26.55            0.96
# 3  630003      Clay     7.68          53.58            0.83
# 4  630004     Loamy     5.23          59.02            0.54
#
#    Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                     2.81          17.83     30.24      1533.38
# 1                     3.26          21.18     78.07       576.05
# 2                     0.85          26.87     60.35       545.30
# 3                     0.55          41.74     36.05      1211.03
# 4                     2.11          41.08     52.47      1321.91
#
#    Sunlight_Hours  Wind_Speed_kmh Crop_Type Crop_Growth_Stage  Season  \
# 0            5.40            3.00     Maize            Sowing    Rabi
# 1            7.22           15.88    Cotton            Sowing    Rabi
# 2            9.43            2.63     Wheat            Sowing  Kharif
# 3            6.69            1.86     Maize           Harvest    Rabi
# 4            4.11            5.71    Cotton            Sowing  Kharif
#
#   Irrigation_Type Water_Source  Field_Area_hectare Mulching_Used  \
# 0           Canal        River               13.59           Yes
# 1            Drip    Reservoir                6.12           Yes
# 2       Sprinkler    Reservoir                3.11           Yes
# 3           Canal  Groundwater                2.27            No
# 4           Canal  Groundwater               12.39           Yes
#
#    Previous_Irrigation_mm   Region
# 0                   47.48     West
# 1                   56.43    South
# 2                   20.00     East
# 3                  102.99    North
# 4                   13.33  Central

# %%
le = LabelEncoder()
train['Irrigation_Need'] = le.fit_transform(train['Irrigation_Need'])

X = train.drop('Irrigation_Need',axis=1)
y=train['Irrigation_Need']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=26, stratify=train['Irrigation_Need'])

# %%
ohe=OneHotEncoder(sparse_output=False,drop="first").set_output(transform="pandas")

trans = ColumnTransformer(
    transformers=[("OHE", ohe, make_column_selector(dtype_include=object))], remainder="passthrough",
    verbose_feature_names_out=False).set_output(transform="pandas")

X_trn_ohe = trans.fit_transform(X_train)
X_tst_ohe = trans.transform(X_test)

scaler = StandardScaler()
X_trn_scl = scaler.fit_transform(X_trn_ohe)
X_tst_scl = scaler.transform(X_tst_ohe)

# %%
# Logistic Regression

solvers = ['lbfgs', 'newton-cg', 'newton-cholesky', 'sag', 'saga']  # Liblinear not works for huge multiclass dataset.
Cs = np.linspace(0.001, 5, 10)
scores = []
for s in tqdm(solvers):
    for c in Cs:
        lr=LogisticRegression(solver=s, C=c)  
        lr.fit(X_trn_scl, y_train)
        y_pred_prob = lr.predict_proba(X_tst_scl)
        scores.append([s, c, log_loss(y_test, y_pred_prob)])
        
df_scores = pd.DataFrame(scores, columns=['solver', 'C', 'Log_Loss'])
df_scores.sort_values('Log_Loss', ascending=False)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [12:51<00:00, 154.21s/it]
#              solver         C  Log_Loss
# 10        newton-cg  0.001000  0.294603
# 40             saga  0.001000  0.294598
# 20  newton-cholesky  0.001000  0.294598
# 30              sag  0.001000  0.294598
# 0             lbfgs  0.001000  0.294597
# 39              sag  5.000000  0.286679
# 38              sag  4.444556  0.286632
# 34              sag  2.222778  0.286623
# 37              sag  3.889111  0.286622
# 11        newton-cg  0.556444  0.286622
# 12        newton-cg  1.111889  0.286622
# 44             saga  2.222778  0.286622
# 13        newton-cg  1.667333  0.286622
# 14        newton-cg  2.222778  0.286622
# 15        newton-cg  2.778222  0.286622
# 16        newton-cg  3.333667  0.286622
# 17        newton-cg  3.889111  0.286622
# 18        newton-cg  4.444556  0.286622
# 19        newton-cg  5.000000  0.286622
# 36              sag  3.333667  0.286622
# 42             saga  1.111889  0.286622
# 31              sag  0.556444  0.286622
# 32              sag  1.111889  0.286622
# 43             saga  1.667333  0.286622
# 21  newton-cholesky  0.556444  0.286622
# 41             saga  0.556444  0.286622
# 45             saga  2.778222  0.286622
# 22  newton-cholesky  1.111889  0.286622
# 23  newton-cholesky  1.667333  0.286621
# 24  newton-cholesky  2.222778  0.286621
# 25  newton-cholesky  2.778222  0.286621
# 26  newton-cholesky  3.333667  0.286621
# 27  newton-cholesky  3.889111  0.286621
# 28  newton-cholesky  4.444556  0.286621
# 29  newton-cholesky  5.000000  0.286621
# 47             saga  3.889111  0.286621
# 48             saga  4.444556  0.286621
# 49             saga  5.000000  0.286621
# 46             saga  3.333667  0.286621
# 33              sag  1.667333  0.286620
# 1             lbfgs  0.556444  0.286619
# 9             lbfgs  5.000000  0.286619
# 8             lbfgs  4.444556  0.286619
# 7             lbfgs  3.889111  0.286619
# 2             lbfgs  1.111889  0.286619
# 6             lbfgs  3.333667  0.286618
# 5             lbfgs  2.778222  0.286618
# 4             lbfgs  2.222778  0.286618
# 3             lbfgs  1.667333  0.286618
# 35              sag  2.778222  0.286617

# %%
# KNN 

Ks=[1,2,3,4,5]
scores=[]

for k in tqdm(Ks):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_trn_scl, y_train)
    y_pred_prob = knn.predict_proba(X_tst_scl)
    scores.append([k, log_loss(y_test, y_pred_prob)])
    
df_scores = pd.DataFrame(scores, columns=['Ks', 'Log_loss score'])
df_scores.sort_values('Log_loss score', ascending=True).head()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [14:46<00:00, 177.25s/it]
#    Ks  Log_loss score
# 4   5        1.160248
# 3   4        1.548164
# 2   3        2.268576
# 1   2        3.952637
# 0   1        8.869790

# %%
# Naive Bayes

nb = GaussianNB()
nb.fit(X_trn_scl,y_train) 
y_pred_prob = nb.predict_proba(X_tst_scl) 
print("Log Loss =", log_loss(y_test, y_pred_prob))
# Out:
# Log Loss = 0.487526663380936

# %% [markdown]
# # Inferencing

# %%
X_ohe = trans.fit_transform(X)
X_scl = scaler.fit_transform(X_ohe)
bm = LogisticRegression(solver = 'newton-cholesky', C = 0.001)
bm.fit(X_scl, y)
# Out:
# LogisticRegression(C=0.001, solver='newton-cholesky')

# %%
test_ohe = trans.transform(test)
test_scl = scaler.transform(test_ohe)

# %%
submit = pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Day6\\playground-series-s6e4 (1)\\sample_submission.csv")
y_pred = bm.predict(test_scl)

y_pred_labels = le.inverse_transform(y_pred)

submit['Irrigation_Need'] = y_pred_labels

# %%
submit
# Out:
#             id Irrigation_Need
# 0       630000             Low
# 1       630001             Low
# 2       630002             Low
# 3       630003             Low
# 4       630004             Low
# ...        ...             ...
# 269995  899995             Low
# 269996  899996             Low
# 269997  899997          Medium
# 269998  899998             Low
# 269999  899999          Medium
#
# [270000 rows x 2 columns]

# %%
submit.to_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Day6\\sbt_log_22_Apr.csv", index=False)
