# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score,log_loss
from sklearn.metrics import classification_report,roc_auc_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from tqdm import tqdm
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
image=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Image_Segmentation\\Image_Segmentation.csv")
image
# Out:
#          Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0    BRICKFACE                  188                  133                   9
# 1    BRICKFACE                  105                  139                   9
# 2    BRICKFACE                   34                  137                   9
# 3    BRICKFACE                   39                  111                   9
# 4    BRICKFACE                   16                  128                   9
# ..         ...                  ...                  ...                 ...
# 204      GRASS                   36                  243                   9
# 205      GRASS                  186                  218                   9
# 206      GRASS                  197                  236                   9
# 207      GRASS                  208                  240                   9
# 208      GRASS                  223                  185                   9
#
# ...

# %%
# le=LabelEncoder()
# image['Class']=le.fit_transform(image['Class'])
X,y=image.drop('Class',axis=1), image['Class']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=26,stratify=image['Class'])

# %%
lda=LinearDiscriminantAnalysis()
lda.fit(X_train,y_train)# cxalculate all the apriori probabilities
y_pred_prob=lda.predict_proba(X_test)# calculates posterior probabilities
print("log_loss=",log_loss(y_test,y_pred_prob))
y_pred=lda.predict(X_test)
print("Accuracy=",accuracy_score(y_test,y_pred))
# Out:
# log_loss= 1.3575030968052337
# Accuracy= 0.9206349206349206

# %%
qda=QuadraticDiscriminantAnalysis(reg_param=0.9)
qda.fit(X_train,y_train)# cxalculate all the apriori probabilities
y_pred_prob=qda.predict_proba(X_test)# calculates posterior probabilities
print("log_loss=",log_loss(y_test,y_pred_prob))
y_pred=qda.predict(X_test)
print("Accuracy=",accuracy_score(y_test,y_pred))
# Out:
# log_loss= 2.0163465691036415
# Accuracy= 0.9206349206349206

# %%
score=[]
for p in np.linspace(0.001, 1.0, 100):
    qda=QuadraticDiscriminantAnalysis(reg_param=p)
    qda.fit(X_train,y_train)
    y_pred_prob=qda.predict_proba(X_test)
    score.append([p,log_loss(y_test,y_pred_prob)])
df_scores=pd.DataFrame(score,columns=['ref-param','score'])
df_scores.sort_values('score')
# Out:
#     ref-param     score
# 1    0.011091  1.860214
# 80   0.808273  1.987356
# 81   0.818364  1.987469
# 79   0.798182  1.987637
# 82   0.828455  1.988038
# ..        ...       ...
# 4    0.041364  2.416448
# 3    0.031273  2.423065
# 2    0.021182  2.428871
# 98   0.989909  3.446874
# 99   1.000000  9.726065
#
# [100 rows x 2 columns]

# %%
image=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Image_Segmentation\\Image_Segmentation.csv")
image
# Out:
#          Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0    BRICKFACE                  188                  133                   9
# 1    BRICKFACE                  105                  139                   9
# 2    BRICKFACE                   34                  137                   9
# 3    BRICKFACE                   39                  111                   9
# 4    BRICKFACE                   16                  128                   9
# ..         ...                  ...                  ...                 ...
# 204      GRASS                   36                  243                   9
# 205      GRASS                  186                  218                   9
# 206      GRASS                  197                  236                   9
# 207      GRASS                  208                  240                   9
# 208      GRASS                  223                  185                   9
#
# ...

# %%
X,y=image.drop('Class',axis=1), image['Class']
lda=LinearDiscriminantAnalysis().set_output(transform="pandas")
X_lda=lda.fit_transform(X,y)
lda_data=pd.concat([X_lda,y],axis=1)
lda_data
# Out:
#      lineardiscriminantanalysis0  lineardiscriminantanalysis1  \
# 0                       0.589119                     4.278844
# 1                       0.450417                     4.154446
# 2                       2.091867                     4.449199
# 3                       0.150416                     4.506612
# 4                       0.823607                     4.340618
# ..                           ...                          ...
# 204                    14.752466                    -1.865171
# 205                    13.371916                    -1.384433
# 206                    12.179366                    -1.335292
# 207                    14.056916                    -1.956963
# 208                    13.565506                    -0.145205
#
#      lineardiscriminantanalysis2  lineardiscriminantanalysis3  \
# 0                       0.857238                     1.634340
# 1                       0.459624                     1.236909
# ...

# %%
X_lda.shape,X.shape
# Out:
# ((209, 6), (209, 19))

# %%
sns.scatterplot(data=lda_data,x="lineardiscriminantanalysis0",y="lineardiscriminantanalysis1",hue="Class")
plt.show()
