# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import root_mean_squared_error as RMSE

# %%
df=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Datasets\\Electric_Production.csv")
df
# Out:
#            DATE  IPG2211A2N
# 0    1985-01-01     72.5052
# 1    1985-02-01     70.6720
# 2    1985-03-01     62.4502
# 3    1985-04-01     57.4714
# 4    1985-05-01     55.3151
# ..          ...         ...
# 392  2017-09-01     98.6154
# 393  2017-10-01     93.6137
# 394  2017-11-01     97.3359
# 395  2017-12-01    114.7212
# 396  2018-01-01    129.4048
#
# [397 rows x 2 columns]

# %%
result=adfuller(df['IPG2211A2N'],maxlag=10)
print("P-Value= ",result[1])
if result[1]<0.05:
    print("Time Series is Stationary")
else:
    print("Time Series is not Stationary")
# Out:
# P-Value=  0.29979017661565055
# Time Series is not Stationary

# %%
diff1=df['IPG2211A2N'].diff().iloc[1:]
result=adfuller(diff1,maxlag=10)
print("P-Value= ",result[1])
if result[1]<0.05:
    print("Time Series is Stationary")
else:
    print("Time Series is not Stationary")
# Out:
# P-Value=  0.0
# Time Series is Stationary

# %%
df=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Datasets\\gdp-per-capita-ppp-constant-2011.csv")
df
# Out:
#     Year  GDP_per_capita
# 0   1990        1754.857
# 1   1991        1737.615
# 2   1992        1796.532
# 3   1993        1845.149
# 4   1994        1930.113
# 5   1995        2036.796
# 6   1996        2149.366
# 7   1997        2194.903
# 8   1998        2288.048
# 9   1999        2445.751
# 10  2000        2495.047
# 11  2001        2570.428
# 12  2002        2623.330
# 13  2003        2783.004
# 14  2004        2955.205
# 15  2005        3178.829
# 16  2006        3419.931
# 17  2007        3698.777
# 18  2008        3786.633
# 19  2009        4049.805
# 20  2010        4404.697
# 21  2011        4635.879
# 22  2012        4827.560
# 23  2013        5073.605
# 24  2014        5385.142
# 25  2015        5756.665
# 26  2016        6095.723
# 27  2017        6426.674

# %%
plot_acf(df['GDP_per_capita'],lags=10,alpha=None)
plt.show()
