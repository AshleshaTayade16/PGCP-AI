# %%
import numpy as np
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
os.chdir("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Datasets")

# %%
house=pd.read_csv("Housing.csv")
house
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
X=house.drop("Price",axis=1)
y=house["Price"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=26)
lr=LinearRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)
print("MAE=",mean_absolute_error(y_test,y_pred))
print("MSE=",root_mean_squared_error(y_test,y_pred))
print("R2=",r2_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 X=house.drop("Price",axis=1)
#       2 y=house["Price"]
#       3 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=26)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
# ...

# %%
dum_tst=pd.get_dummies(house)
dum_tst
# Out:
#         price  lotsize  bedrooms  bathrms  stories  garagepl  driveway_no  \
# 0     42000.0     5850         3        1        2         1        False
# 1     38500.0     4000         2        1        1         0        False
# 2     49500.0     3060         3        1        1         0        False
# 3     60500.0     6650         3        1        2         0        False
# 4     61000.0     6360         2        1        1         0        False
# ..        ...      ...       ...      ...      ...       ...          ...
# 541   91500.0     4800         3        2        4         0        False
# 542   94000.0     6000         3        2        4         0        False
# 543  103000.0     6000         3        2        4         1        False
# 544  105000.0     6000         3        2        2         1        False
# 545  105000.0     6000         3        1        2         1        False
#
#      driveway_yes  recroom_no  recroom_yes  fullbase_no  fullbase_yes  \
# ...

# %%
bm=LinearRegression()
bm.fit(X,y)
X.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 bm=LinearRegression()
# ----> 2 bm.fit(X,y)
#       3 X.columns
#
# NameError: name 'X' is not defined

# %%
dum_tst['driveway_yes']=[True, True, True, True]
dum_tst['gashw_yes']=False
dum_tst['airco_yes']=False
dum_tst['prefarea_yes']=False
dum_tst=dum_tst[['lotsize','bedrooms','bathrms','stories','garagepl','driveway_yes','recroom_yes',
                'fullbase_yes','gashw_yes','airco_yes','prefarea_yes']]
dum_tst.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dum_tst['driveway_yes']=[True, True, True, True]
#       2 dum_tst['gashw_yes']=False
#       3 dum_tst['airco_yes']=False
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
# ...
