# %%
import surprise
import pandas as pd
import numpy as np
from surprise.model_selection import GridSearchCV
from surprise.model_selection.split import KFold

# %%
amazon=pd.read_csv("D:\\AshleshaRuchika\\PGCP-AI\\Machine Learning\\Cases_Rec_Sys\\Amazon Movie Ratings\\Amazon.csv",encoding='latin-1')
print(amazon.columns)
amazon
# Out:
# Index(['user_id', 'Movie1', 'Movie2', 'Movie3', 'Movie4', 'Movie5', 'Movie6',
#        'Movie7', 'Movie8', 'Movie9',
#        ...
#        'Movie197', 'Movie198', 'Movie199', 'Movie200', 'Movie201', 'Movie202',
#        'Movie203', 'Movie204', 'Movie205', 'Movie206'],
#       dtype='str', length=207)
#              user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0     A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1      AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2     A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3      AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4     A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 4843  A1IMQ9WMFYKWH5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
ratings=pd.melt(amazon,id_vars='user_id',var_name='item_id',value_name='rating')
ratings=ratings[ratings['rating'].notna()]
ratings
# Out:
#                user_id   item_id  rating
# 0       A3R5OBKS7OM2IR    Movie1     5.0
# 4848    A3R5OBKS7OM2IR    Movie2     5.0
# 9697     AH3QC2PC1VTGP    Movie3     2.0
# 14546   A3LKP6WPMP9UKX    Movie4     5.0
# 14547    AVIY68KEPQ5ZD    Movie4     5.0
# ...                ...       ...     ...
# 998683  A1IMQ9WMFYKWH5  Movie206     5.0
# 998684  A1KLIKPUF5E88I  Movie206     5.0
# 998685   A5HG6WFZLO10D  Movie206     5.0
# 998686  A3UU690TWXCG1X  Movie206     5.0
# 998687   AI4J762YI6S06  Movie206     5.0
#
# [5000 rows x 3 columns]
