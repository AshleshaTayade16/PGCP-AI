# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# Your Name and PRN:
# - Name: Ashish Mulani
# - PRN : 260240128007
# - Date: 22/05/26
# -------------------------------
# - Name: Pranita Lad
# - PRN : 260240128028
# - Date: 22/05/26

# %% [markdown]
# # Deep Neural Network
# ## Assignment A04
#
# ## Tensor Flow
# - Select number of layers
# - Select node in each of the layers
# - Choose activation function
# - multi-class - Fashion MNIST dataset (all 60000 images)
# - Implement one or more of following to achieve max accuracy.
#     - L1/ L2 Regularization
#     - Dropout
#     - Batch Normalization
#     - Early stopping
# - Save model

# %%
###-----------------
### Import Libraries
###-----------------
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay, confusion_matrix, f1_score

import tensorflow as tf

# from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###-----------------
### Global Variables
###-----------------
inpDir   = r'D:\Deep_Learning\SharedData'
outDir   = '../output'
modelDir = '../models'
subDir   = 'fashion_mnist'
altName  = 'A04_fashion_cnn'

RANDOM_STATE = 24
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

# parameters for Matplotlib
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'large',
          'axes.titlesize': 'x-large',
          'xtick.labelsize': 'large',
          'ytick.labelsize': 'large'
         }

CMAP = 'brg'
plt.rcParams.update(params)
plt.style.use('seaborn-v0_8-darkgrid')

# %%
###-----------------
### Hyper Parameters
###-----------------
EPOCHS     = 60       # number of epochs
ALPHA      = 0.0005    # learning rate
BATCH_SIZE = 64       # mini batch size
PATIENCE   = 15

# %% [markdown]
# ## Helper Functions

# %%
def fn_plot_labels(train_df, test_df):
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 2, 1)
    train_df['label'].value_counts().plot(kind='bar',
                                          title='Train',
                                          color='DarkBlue',
                                          alpha=0.7)

    plt.subplot(1, 2, 2)
    test_df['label'].value_counts().plot(kind='bar',
                                         title='Test',
                                         color='Orange',
                                         alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Load Fashion MNIST dataset

# %% [markdown]
# This guide uses the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen here:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fashion MNIST is intended as a drop-in replacement for the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset—often used as the "Hello, World" of machine learning programs for computer vision. The MNIST dataset contains images of handwritten digits (0, 1, 2, etc.) in a format identical to that of the articles of clothing you'll use here.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images.

# %%
#class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

class_names = {0: 'T-shirt/top', 1: 'Trouser',   2: 'Pullover', 3: 'Dress', 4: 'Coat',
               5: 'Sandal',      6: 'Shirt',      7: 'Sneaker',  8: 'Bag',   9: 'Ankle boot'}

# %%
import os

local_path = r'D:\Deep_Learning\SharedData\fashion-mnist_train.csv'

if os.path.exists(local_path):
    # ── Local VS Code ──
    inpDir         = r'D:\Deep_Learning\SharedData'
    train_filename = os.path.join(inpDir, 'fashion-mnist_train.csv')
    test_filename  = os.path.join(inpDir, 'fashion-mnist_test.csv')
    train_df = pd.read_csv(train_filename, header=0)
    test_df  = pd.read_csv(test_filename,  header=0)

else:
    # ── Google Colab ──
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
    train_df = pd.DataFrame(X_train.reshape(-1, 784))
    train_df.columns = train_df.columns.astype(str) # Convert pixel column names to string
    train_df.insert(0, 'label', y_train)
    test_df = pd.DataFrame(X_test.reshape(-1, 784))
    test_df.columns = test_df.columns.astype(str) # Convert pixel column names to string
    test_df.insert(0, 'label', y_test)

print('Train shape:', train_df.shape)
print('Test shape :', test_df.shape)
# Out:
# Train shape: (60000, 785)
# Test shape : (10000, 785)

# %%
def split_feature_label(row_dict):
    label = row_dict['label']

    # Feature columns are named '0' through '783' (now as strings)
    feature_keys = [str(i) for i in range(784)]
    features = tf.stack([row_dict[key] for key in feature_keys])

    features = tf.cast(features, tf.float32)
    features = tf.reshape(features, (28, 28, 1))

    return features, label

# %%
tmp_ds   = tf.data.Dataset.from_tensor_slices(dict(train_df))
train_ds = tmp_ds.map(split_feature_label)

train_ds = train_ds.cache()
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

# %%
for images, labels in train_ds.take(1):
    for i in range(BATCH_SIZE):
        plt.subplot(BATCH_SIZE // 8, 8, i + 1)
        plt.grid(False)
        plt.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary)
        plt.title(class_names[labels[i].numpy()], fontsize=7)
        plt.axis('off')
plt.tight_layout()

# %% [markdown]
# # Define Model
#
# ### Architecture
# ```
# Input: 28 x 28 x 1 (grayscale)
#
# Set 1: Conv2D(32, 3x3, same) → BatchNorm → ReLU → MaxPool(2,2) → Dropout(0.1)  → 14x14x32
# Set 2: Conv2D(64, 3x3)       → BatchNorm → ReLU → MaxPool(2,2) → Dropout(0.2)  →  6x6x64
# Set 3: Conv2D(128, 3x3)      → BatchNorm → ReLU              → Dropout(0.3)  →  4x4x128
#
# Flatten → 2048
# Dense(128) → BatchNorm → ReLU → Dropout(0.4)
# Dense(10)  → logits
# ```

# %%
from tensorflow.keras import regularizers
krnal_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)

input_shape = (28, 28, 1)


dor1 = 0.2
dor2 = 0.3
dor3 = 0.3
dor4 = 0.4

model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=input_shape))
model.add(tf.keras.layers.Rescaling(1./255.))

# Set 1
model.add(tf.keras.layers.Conv2D(32, (3,3),
                                 kernel_initializer=krnal_init,
                                 padding='same'))          # (28 x 28 x 32)
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.MaxPool2D())                     # (14 x 14 x 32)
model.add(tf.keras.layers.Dropout(rate=dor1))

# Set 2
model.add(tf.keras.layers.Conv2D(64, (3,3),
                                 kernel_initializer=krnal_init))   # (12 x 12 x 64)
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.MaxPool2D())                     # (6 x 6 x 64)
model.add(tf.keras.layers.Dropout(rate=dor2))

# Set 3
model.add(tf.keras.layers.Conv2D(128, (3,3),
                                 kernel_initializer=krnal_init))   # (4 x 4 x 128)
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(rate=dor3))

### Head
model.add(tf.keras.layers.Flatten())                       # (2048)

# Dense 1 — add L2
model.add(tf.keras.layers.Dense(128,
                                kernel_initializer=krnal_init,
                                kernel_regularizer=regularizers.l2(1e-4)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(rate=dor4))

# Dense 2 — output logits
model.add(tf.keras.layers.Dense(10,
                                kernel_initializer=krnal_init))    # (10)

print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 12, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 357,642 (1.36 MB)
#  Trainable params: 356,938 (1.36 MB)
#  Non-trainable params: 704 (2.75 KB)
# None

# %%
loss_fn   = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA,
                                     clipnorm = 1.0)

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %% [markdown]
# ## Callbacks — Early Stopping

# %%
# ── Model checkpoint ──
os.makedirs(os.path.join(modelDir, subDir), exist_ok=True)
checkpoint_filepath = os.path.join(modelDir, subDir, f'{altName}.weights.h5')

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True
)

# ── Early stopping ──
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    mode='auto',
    restore_best_weights=True
)

# ── Reduce LR on plateau ──
reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=4,
    min_lr=1e-7,
    verbose=1
)

# %%
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stopping_callback,
               model_checkpoint_callback,
               reduce_lr_callback]
)
# Out:
# Epoch 1/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 93s 87ms/step - accuracy: 0.7933 - loss: 0.6086 - val_accuracy: 0.8782 - val_loss: 0.3684 - learning_rate: 5.0000e-04
# Epoch 2/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8635 - loss: 0.4064 - val_accuracy: 0.8916 - val_loss: 0.3267 - learning_rate: 5.0000e-04
# Epoch 3/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8795 - loss: 0.3661 - val_accuracy: 0.8934 - val_loss: 0.3150 - learning_rate: 5.0000e-04
# Epoch 4/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8875 - loss: 0.3398 - val_accuracy: 0.9002 - val_loss: 0.2995 - learning_rate: 5.0000e-04
# Epoch 5/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8946 - loss: 0.3232 - val_accuracy: 0.9031 - val_loss: 0.2923 - learning_rate: 5.0000e-04
# Epoch 6/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8976 - loss: 0.3154 - val_accuracy: 0.9104 - val_loss: 0.2729 - learning_rate: 5.0000e-04
# Epoch 7/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9037 - loss: 0.3007 - val_accuracy: 0.9089 - val_loss: 0.2771 - learning_rate: 5.0000e-04
# Epoch 8/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9058 - loss: 0.2919 - val_accuracy: 0.9145 - val_loss: 0.2654 - learning_rate: 5.0000e-04
# Epoch 9/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9071 - loss: 0.2863 - val_accuracy: 0.9170 - val_loss: 0.2618 - learning_rate: 5.0000e-04
# Epoch 10/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9109 - loss: 0.2780 - val_accuracy: 0.9155 - val_loss: 0.2628 - learning_rate: 5.0000e-04
# Epoch 11/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9127 - loss: 0.2720 - val_accuracy: 0.9180 - val_loss: 0.2590 - learning_rate: 5.0000e-04
# Epoch 12/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9135 - loss: 0.2692 - val_accuracy: 0.9176 - val_loss: 0.2530 - learning_rate: 5.0000e-04
# Epoch 13/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9150 - loss: 0.2653 - val_accuracy: 0.9201 - val_loss: 0.2501 - learning_rate: 5.0000e-04
# Epoch 14/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9185 - loss: 0.2596 - val_accuracy: 0.9223 - val_loss: 0.2483 - learning_rate: 5.0000e-04
# Epoch 15/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9194 - loss: 0.2572 - val_accuracy: 0.9181 - val_loss: 0.2532 - learning_rate: 5.0000e-04
# Epoch 16/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9198 - loss: 0.2540 - val_accuracy: 0.9240 - val_loss: 0.2434 - learning_rate: 5.0000e-04
# Epoch 17/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9212 - loss: 0.2501 - val_accuracy: 0.9213 - val_loss: 0.2468 - learning_rate: 5.0000e-04
# Epoch 18/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9237 - loss: 0.2437 - val_accuracy: 0.9244 - val_loss: 0.2461 - learning_rate: 5.0000e-04
# Epoch 19/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9250 - loss: 0.2425 - val_accuracy: 0.9225 - val_loss: 0.2510 - learning_rate: 5.0000e-04
# Epoch 20/60
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9247 - loss: 0.2382
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9234 - loss: 0.2428 - val_accuracy: 0.9218 - val_loss: 0.2518 - learning_rate: 5.0000e-04
# Epoch 21/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9310 - loss: 0.2252 - val_accuracy: 0.9276 - val_loss: 0.2303 - learning_rate: 1.5000e-04
# Epoch 22/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9306 - loss: 0.2212 - val_accuracy: 0.9292 - val_loss: 0.2293 - learning_rate: 1.5000e-04
# Epoch 23/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9331 - loss: 0.2146 - val_accuracy: 0.9318 - val_loss: 0.2237 - learning_rate: 1.5000e-04
# Epoch 24/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9345 - loss: 0.2103 - val_accuracy: 0.9319 - val_loss: 0.2215 - learning_rate: 1.5000e-04
# Epoch 25/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9362 - loss: 0.2069 - val_accuracy: 0.9329 - val_loss: 0.2208 - learning_rate: 1.5000e-04
# Epoch 26/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9358 - loss: 0.2052 - val_accuracy: 0.9321 - val_loss: 0.2182 - learning_rate: 1.5000e-04
# Epoch 27/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9356 - loss: 0.2016 - val_accuracy: 0.9331 - val_loss: 0.2176 - learning_rate: 1.5000e-04
# Epoch 28/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9363 - loss: 0.1999 - val_accuracy: 0.9329 - val_loss: 0.2152 - learning_rate: 1.5000e-04
# Epoch 29/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9369 - loss: 0.1971 - val_accuracy: 0.9331 - val_loss: 0.2169 - learning_rate: 1.5000e-04
# Epoch 30/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9385 - loss: 0.1944 - val_accuracy: 0.9322 - val_loss: 0.2127 - learning_rate: 1.5000e-04
# Epoch 31/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9402 - loss: 0.1938 - val_accuracy: 0.9338 - val_loss: 0.2108 - learning_rate: 1.5000e-04
# Epoch 32/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9393 - loss: 0.1911 - val_accuracy: 0.9337 - val_loss: 0.2133 - learning_rate: 1.5000e-04
# Epoch 33/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9401 - loss: 0.1884 - val_accuracy: 0.9345 - val_loss: 0.2124 - learning_rate: 1.5000e-04
# Epoch 34/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9393 - loss: 0.1880 - val_accuracy: 0.9326 - val_loss: 0.2119 - learning_rate: 1.5000e-04
# Epoch 35/60
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.1844
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9410 - loss: 0.1853 - val_accuracy: 0.9306 - val_loss: 0.2153 - learning_rate: 1.5000e-04
# Epoch 36/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9429 - loss: 0.1812 - val_accuracy: 0.9333 - val_loss: 0.2096 - learning_rate: 4.5000e-05
# Epoch 37/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9430 - loss: 0.1778 - val_accuracy: 0.9335 - val_loss: 0.2090 - learning_rate: 4.5000e-05
# Epoch 38/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9427 - loss: 0.1775 - val_accuracy: 0.9341 - val_loss: 0.2105 - learning_rate: 4.5000e-05
# Epoch 39/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9440 - loss: 0.1760 - val_accuracy: 0.9347 - val_loss: 0.2082 - learning_rate: 4.5000e-05
# Epoch 40/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9437 - loss: 0.1753 - val_accuracy: 0.9341 - val_loss: 0.2086 - learning_rate: 4.5000e-05
# Epoch 41/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9445 - loss: 0.1731 - val_accuracy: 0.9347 - val_loss: 0.2082 - learning_rate: 4.5000e-05
# Epoch 42/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9444 - loss: 0.1730 - val_accuracy: 0.9341 - val_loss: 0.2086 - learning_rate: 4.5000e-05
# Epoch 43/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9444 - loss: 0.1741 - val_accuracy: 0.9338 - val_loss: 0.2068 - learning_rate: 4.5000e-05
# Epoch 44/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9447 - loss: 0.1733 - val_accuracy: 0.9354 - val_loss: 0.2064 - learning_rate: 4.5000e-05
# Epoch 45/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9457 - loss: 0.1712 - val_accuracy: 0.9358 - val_loss: 0.2056 - learning_rate: 4.5000e-05
# Epoch 46/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9458 - loss: 0.1704 - val_accuracy: 0.9343 - val_loss: 0.2062 - learning_rate: 4.5000e-05
# Epoch 47/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9451 - loss: 0.1717 - val_accuracy: 0.9346 - val_loss: 0.2059 - learning_rate: 4.5000e-05
# Epoch 48/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9470 - loss: 0.1685 - val_accuracy: 0.9350 - val_loss: 0.2053 - learning_rate: 4.5000e-05
# Epoch 49/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9466 - loss: 0.1671 - val_accuracy: 0.9352 - val_loss: 0.2053 - learning_rate: 4.5000e-05
# Epoch 50/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9457 - loss: 0.1686 - val_accuracy: 0.9346 - val_loss: 0.2045 - learning_rate: 4.5000e-05
# Epoch 51/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9464 - loss: 0.1671 - val_accuracy: 0.9351 - val_loss: 0.2050 - learning_rate: 4.5000e-05
# Epoch 52/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9469 - loss: 0.1655 - val_accuracy: 0.9339 - val_loss: 0.2048 - learning_rate: 4.5000e-05
# Epoch 53/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9461 - loss: 0.1683 - val_accuracy: 0.9349 - val_loss: 0.2035 - learning_rate: 4.5000e-05
# Epoch 54/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9464 - loss: 0.1654 - val_accuracy: 0.9331 - val_loss: 0.2100 - learning_rate: 4.5000e-05
# Epoch 55/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9472 - loss: 0.1640 - val_accuracy: 0.9358 - val_loss: 0.2032 - learning_rate: 4.5000e-05
# Epoch 56/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9480 - loss: 0.1634 - val_accuracy: 0.9347 - val_loss: 0.2027 - learning_rate: 4.5000e-05
# Epoch 57/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9459 - loss: 0.1644 - val_accuracy: 0.9354 - val_loss: 0.2022 - learning_rate: 4.5000e-05
# Epoch 58/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9480 - loss: 0.1628 - val_accuracy: 0.9356 - val_loss: 0.2045 - learning_rate: 4.5000e-05
# Epoch 59/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9480 - loss: 0.1621 - val_accuracy: 0.9346 - val_loss: 0.2025 - learning_rate: 4.5000e-05
# Epoch 60/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9467 - loss: 0.1623 - val_accuracy: 0.9348 - val_loss: 0.2039 - learning_rate: 4.5000e-05

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss  learning_rate
# 0  0.793350  0.608616        0.8782  0.368420         0.0005
# 1  0.863533  0.406432        0.8916  0.326740         0.0005
# 2  0.879450  0.366124        0.8934  0.314996         0.0005
# 3  0.887500  0.339783        0.9002  0.299457         0.0005
# 4  0.894567  0.323197        0.9031  0.292264         0.0005

# %%
def fn_plot_tf_hist(hist_df):

    '''
    Args:
        hist_df: a DataFrame with column names accuracy,loss	val_accuracy	val_loss
    '''

    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y4] == hist_df[y4].min()]

    ax = axes[0]

    hist_df.plot(y = [y2,y4], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arrow
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    best_idx = best.index.to_numpy()[0]  # Extract first (and only) element as scalar
    best_value = best[y4].to_numpy()[0]   # Extract scalar value

    # Mark arrow at lowest
    ax.annotate(f'Min: {best_value:6.4f}', # text to print
                xy=(best_idx, best_value), # Arrow start
                xytext=(best_idx, best_value + offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best_idx, color = 'green', linestyle='-.', lw = 3)

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.set_title('Loss Curve')
    ax.grid(True)
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y1, y3], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0

    best_value = best[y3].to_numpy()[0]   # Extract scalar value
    # Mark arrow at lowest
    ax.annotate(f'Best: {best_value:6.4f}', # text to print
                xy=(best_idx, best_value), # Arrow start
                xytext=(best_idx, best_value-offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best_idx, color = 'green', linestyle='-.', lw = 3)

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Accuracy Curve')
    ax.grid(True)
    ax.legend(loc = 'lower left')

    plt.tight_layout()

# %%
fn_plot_tf_hist(loss_df)

# %% [markdown]
# ## Prediction on Train dataset

# %%
y_true, y_pred = [], []

for features, labels in train_ds:
    pred = model(features, training=False)
    pred = pred.numpy().argmax(axis=1)
    y_pred.append(pred)
    y_true.append(labels.numpy())

y_true, y_pred = np.concatenate(y_true), np.concatenate(y_pred)

accuracy_score(y_true, y_pred)
# Out:
# 0.9736166666666667

# %%
print(classification_report(y_true, y_pred, target_names=list(class_names.values())))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.95      0.95      0.95      6000
#      Trouser       1.00      1.00      1.00      6000
#     Pullover       0.96      0.96      0.96      6000
#        Dress       0.97      0.98      0.98      6000
#         Coat       0.96      0.96      0.96      6000
#       Sandal       1.00      1.00      1.00      6000
#        Shirt       0.92      0.91      0.92      6000
#      Sneaker       0.98      1.00      0.99      6000
#          Bag       1.00      1.00      1.00      6000
#   Ankle boot       0.99      0.98      0.99      6000
#
#     accuracy                           0.97     60000
#    macro avg       0.97      0.97      0.97     60000
# weighted avg       0.97      0.97      0.97     60000

# %%
def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth
        y_pred : Predictions
        labels : labels in a dictonary
                  {0: 'Goal Keeper',
                  1: 'Defender',
                  2: 'Mid-Fielder',
                  3: 'Forward'}

    '''

    cm  = confusion_matrix(y_true, y_pred)

    if isinstance(labels, dict):
        display_labels = labels.values()
    else:
        display_labels = labels

    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=display_labels)

    fig, ax = plt.subplots(figsize = (5,5))

    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)

    # Disable the grid
    ax.grid(False)

    title_str = f"F1 Score : {f1_score(y_true, y_pred, average='weighted'):0.5f}"
    ax.set_title(title_str)

    plt.show()

# %%
fn_plot_confusion_matrix(y_true, y_pred, labels=class_names)

# %% [markdown]
# ## Prediction on Test dataset

# %%
y_true, y_pred = [], []

for features, labels in test_ds:
    pred = model(features, training=False)
    pred = pred.numpy().argmax(axis=1)
    y_pred.append(pred)
    y_true.append(labels.numpy())

y_true, y_pred = np.concatenate(y_true), np.concatenate(y_pred)

accuracy_score(y_true, y_pred)
# Out:
# 0.9354

# %%
print(classification_report(y_true, y_pred, target_names=list(class_names.values())))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.90      0.88      0.89      1000
#      Trouser       1.00      0.98      0.99      1000
#     Pullover       0.91      0.90      0.91      1000
#        Dress       0.93      0.94      0.94      1000
#         Coat       0.89      0.91      0.90      1000
#       Sandal       0.99      0.98      0.99      1000
#        Shirt       0.80      0.81      0.80      1000
#      Sneaker       0.95      0.99      0.97      1000
#          Bag       0.99      0.99      0.99      1000
#   Ankle boot       0.98      0.96      0.97      1000
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
fn_plot_confusion_matrix(y_true, y_pred, labels=class_names)

# %% [markdown]
# ## Save Model

# %%
# save_path = os.path.join(modelDir, subDir, f'{altName}.keras')
# model.save(save_path)
# print(f'Model saved to: {save_path}')
