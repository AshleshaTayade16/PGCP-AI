# %%
from pathlib import Path  # Import Path for file system path operations and management
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.metrics import (accuracy_score,
                             classification_report, 
                            confusion_matrix,
                            ConfusionMatrixDisplay,
                            f1_score)

# %%
inpDir = Path('..') / '..' / 'input'

outDir = Path('..') / '..' / 'input'


RANDOM_STATE = 24

rng = np.random.default_rng(seed = RANDOM_STATE)

NOISE = 0.2
EPOCHS = 50000
ALPHA = 0.001
N_SAMPLE = 1000
TEST_SIZE = 0.2

# Parameters for plotting
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params)

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
def fn_plot_decision_boundary(model: dict,
                              X_tr: np.ndarray,
                              y_tr: np.ndarray,
                              X_ts: np.ndarray,
                              y_ts: np.ndarray):
    """
    model : trained nn network model
    X_tr : train feature matrix
    y_tr : train labels
    X_ts : test feature matrix
    y_ts : test labels
    """
    
    fig, ax = plt.subplots(figsize=(8, 5))
    
    dm = 0.05
    padding = 2 * dm
    
    # Use training set for boundary range
    x_min, x_max = X_tr[:, 0].min() - padding, X_tr[:, 0].max() + padding
    y_min, y_max = X_tr[:, 1].min() - padding, X_tr[:, 1].max() + padding
    
    xx, yy = np.meshgrid(np.arange(x_min, x_max, dm),
                         np.arange(y_min, y_max, dm))
    
    # Predict over grid
    grid_points = np.c_[xx.ravel(), yy.ravel()]
    Z = fn_predict(model, grid_points).reshape(xx.shape)
    
    # Decision regions
    ax.contourf(xx, yy, Z, alpha=0.6, cmap=plt.cm.Paired)
    
    # Training points
    ax.scatter(X_tr[:, 0], X_tr[:, 1], c=y_tr.ravel(), s=20, edgecolor='k', cmap=plt.cm.bwr, label="Train")
    
    # Test points
    ax.scatter(X_ts[:, 0], X_ts[:, 1], c=y_ts.ravel(), s=20, edgecolor='k', cmap=plt.cm.coolwarm, marker='x', label="Test")
    
    ax.set_title('Decision Boundary')
    ax.set_xlabel('A')
    ax.set_ylabel('B')
    ax.legend()
    plt.show()

# %%
X, y = datasets.make_moons(n_samples=N_SAMPLE, 
                           noise=NOISE,
                           shuffle=True, 
                           random_state=RANDOM_STATE)
X[:5], y[:5]
# Out:
# (array([[ 0.90633951,  0.90267624],
#         [-1.11536828,  0.75579289],
#         [ 1.88769158,  0.4175967 ],
#         [-0.93345034, -0.02299851],
#         [-0.96872877,  0.06396285]]),
#  array([0, 0, 1, 0, 0]))

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,random_state=RANDOM_STATE,test_size=TEST_SIZE)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %%
def fn_sigmoid(z: np.float64):
    return 1 / (1 + np.exp(-z))

# %%
sm = fn_sigmoid(np.array([[-1,0,1],[-np.inf,0.,np.inf]]))
sm
# Out:
# array([[0.26894142, 0.5       , 0.73105858],
#        [0.        , 0.5       , 1.        ]])

# %% [markdown]
# ### Tanh Activation Functions

# %%
def fn_activ(z):
    return np.tanh(z)
def fn_activ_prime(z):
    return 1-np.tanh(z)**2

# %%
fn_activ(np.array([[-1,0,1],[-np.inf,0.,np.inf]]))
# Out:
# array([[-0.76159416,  0.        ,  0.76159416],
#        [-1.        ,  0.        ,  1.        ]])

# %%
np.tanh(0.5),(1-np.power(np.tanh(0.5),2)),fn_activ_prime(0.5)
# Out:
# (np.float64(0.46211715726000974),
#  np.float64(0.7864477329659274),
#  np.float64(0.7864477329659274))

# %% [markdown]
# ## Back propogation

# %%
def fn_predict(model,X_p):
    W1,W2,b1,b2=model['W1'],model['W2'],model['b1'],model['b2']    
    z1=X_p.dot(W1)+b1
    a1=fn_activ(z1)

    z2=a1.dot(W2)+b2
    a2=fn_sigmoid(z2)
    return (a2>=0.5).astype(int)

# %%
def fn_calculate_loss(model,X_l,y_l):
    W1,W2,b1,b2=model['W1'],model['W2'],model['b1'],model['b2']
    m=X_l.shape[0]
    
    z1=X_l.dot(W1)+b1
    a1=fn_activ(z1)

    z2=a1.dot(W2)+b2
    a2=fn_sigmoid(z2)

    data_loss=-(y_l*np.log(a2)+(1-y_l)*np.log(1-a2)).sum()
    return data_loss/m

# %%
 def fn_build_model(nn_hdim,X,y,n_epochs=EPOCHS,alpha=ALPHA):
    m,nn_input_dim=X.shape
    nn_output_dim=y.shape[1]
    W1=rng.random((nn_input_dim,nn_hdim),dtype=np.float32) / np.sqrt(nn_input_dim)
    W2=rng.random((nn_hdim,nn_output_dim),dtype=np.float32) / np.sqrt(nn_hdim)

    b1=np.zeros((1,nn_hdim),dtype=np.float32)
    b2=np.zeros((1,nn_output_dim),dtype=np.float32)

    curr_loss=0
    loss, epoch=[],[]

    for i in range(n_epochs):
        ### Forward Propagation 
        z1=X.dot(W1)+b1
        a1=fn_activ(z1)

        z2=a1.dot(W2)+b2
        a2=fn_sigmoid(z2)
       
        ### Back Propagation
        dz2=a2-y
        assert(z2.shape==dz2.shape),f'Shape Mismatch z2{z2.shape} and {dz2.shape}'
        
        dW2=(a1.T).dot(dz2)
        assert(W2.shape==dW2.shape),f'SM W2 {W2.shape} and {dW2.shape}'

        db2=np.sum(dz2,axis=0,keepdims=True)
        assert(b2.shape==db2.shape),f'SM b2 {b2.shape} and {db2.shape}'

        da1=dz2.dot(W2.T)
        assert(a1.shape==da1.shape),f'SM a1 {a1.shape} and {da1.shape}'

        dz1=da1*fn_activ_prime(z1)
        assert(z1.shape==dz1.shape),f'SM z1 {z1.shape} and {dz1.shape}'

        dW1=(X.T).dot(dz1)
        assert(W1.shape==dW1.shape),f'SM W1 {W1.shape} and {dW1.shape}'

        db1=np.sum(dz1,axis=0,keepdims=True)
        assert(b1.shape==db1.shape),f'SM b1 {b1.shape} and {db1.shape}'

        #gradient update
        W1=W1-alpha*dW1/m #element wise multiplication
        W2=W2-alpha*dW2/m 
        b1=b1-alpha*db1/m 
        b2=b2-alpha*db2/m 
        
        model={"W1":W1,"b1":b1,"W2":W2,"b2":b2}

        if i%100==0:
            curr_loss=fn_calculate_loss(model,X,y)
            loss.append(curr_loss)
            epoch.append(i)

            if i%1000==0:
                print(f'Loss after epoch {i:>5d}: {curr_loss:.5f}')
    return model, loss, epoch

# %%
y_train=y_train.reshape(-1,1)
y_train.shape
# Out:
# (800, 1)

# %%
nn_hdim=4
model,loss,epoch=fn_build_model(nn_hdim,X_train,y_train,n_epochs=EPOCHS,alpha=ALPHA)
model
# Out:
# Loss after epoch     0: 0.69681
# Loss after epoch  1000: 0.66913
# Loss after epoch  2000: 0.64496
# Loss after epoch  3000: 0.62055
# Loss after epoch  4000: 0.59472
# Loss after epoch  5000: 0.56770
# Loss after epoch  6000: 0.54041
# Loss after epoch  7000: 0.51388
# Loss after epoch  8000: 0.48889
# Loss after epoch  9000: 0.46589
# Loss after epoch 10000: 0.44508
# Loss after epoch 11000: 0.42645
# Loss after epoch 12000: 0.40989
# Loss after epoch 13000: 0.39524
# Loss after epoch 14000: 0.38233
# Loss after epoch 15000: 0.37099
# Loss after epoch 16000: 0.36105
# Loss after epoch 17000: 0.35235
# Loss after epoch 18000: 0.34477
# Loss after epoch 19000: 0.33817
# Loss after epoch 20000: 0.33245
# Loss after epoch 21000: 0.32748
# Loss after epoch 22000: 0.32319
# Loss after epoch 23000: 0.31949
# Loss after epoch 24000: 0.31629
# Loss after epoch 25000: 0.31354
# Loss after epoch 26000: 0.31117
# Loss after epoch 27000: 0.30912
# Loss after epoch 28000: 0.30737
# Loss after epoch 29000: 0.30585
# Loss after epoch 30000: 0.30455
# Loss after epoch 31000: 0.30342
# Loss after epoch 32000: 0.30244
# Loss after epoch 33000: 0.30160
# Loss after epoch 34000: 0.30086
# Loss after epoch 35000: 0.30022
# Loss after epoch 36000: 0.29967
# Loss after epoch 37000: 0.29918
# Loss after epoch 38000: 0.29876
# Loss after epoch 39000: 0.29838
# Loss after epoch 40000: 0.29805
# Loss after epoch 41000: 0.29776
# Loss after epoch 42000: 0.29750
# Loss after epoch 43000: 0.29727
# Loss after epoch 44000: 0.29706
# Loss after epoch 45000: 0.29687
# Loss after epoch 46000: 0.29670
# Loss after epoch 47000: 0.29655
# Loss after epoch 48000: 0.29641
# Loss after epoch 49000: 0.29628
# {'W1': array([[ 0.15750349,  0.37245277,  0.3510369 ,  0.35322378],
#         [ 0.93397693, -0.41572613, -1.51349133, -0.77735554]]),
#  'b1': array([[-0.19982045,  0.02409889,  0.11857288,  0.0174478 ]]),
#  'W2': array([[-0.82852005],
#         [ 0.63017489],
#         [ 2.2421713 ],
#         [ 1.0673863 ]]),
#  'b2': array([[0.06086748]])}

# %%
loss_hist={}
loss_hist['loss']=loss
loss_hist['epoch']=epoch
pd.DataFrame(loss_hist).plot(x='epoch',y='loss')
# Out:
# <Axes: xlabel='epoch'>

# %%
y_pred = fn_predict(model,X_train)
print('Accuracy on train: ',accuracy_score(y_train,y_pred))
# Out:
# Accuracy on train:  0.8725

# %%
y_pred = fn_predict(model,X_test)
print('Accuracy on test data', accuracy_score(y_test,y_pred))
# Out:
# Accuracy on test data 0.855

# %%
fn_plot_decision_boundary(model, X_train, y_train, X_test, y_test)
# Out:
# C:\Users\PGCP-AI\AppData\Local\Temp\ipykernel_1544\3855278400.py:37: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(X_ts[:, 0], X_ts[:, 1], c=y_ts.ravel(), s=20, edgecolor='k', cmap=plt.cm.coolwarm, marker='x', label="Test")
