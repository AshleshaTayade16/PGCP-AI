# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
# ## Session 14a
#
# ## Sequential Model using ionosphere putting it together
#
# 1. Monitor validation set as well as training set
# 2. L2 Regularization
# 3. Dropouts
# 4. Batch Norm
# 5. Early stopping
#
# <img src='../../prasami_images/prasami_color_tutorials_small.png' style = 'width:400px;' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
# Lets import some libraries
from pathlib import Path
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler, LabelEncoder

import tensorflow as tf

from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %matplotlib inline
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778583860.399973  121114 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Some basic parameters

inpDir = Path('../../input') # location where input data is stored
outDir = Path('../output') # location to store outputs
modelDir = Path('../models')
logDir = Path('../logs')
subDir = 'ionosphere'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well


EPOCHS = 100         # number of epochs
ALPHA = 0.001        # learning rate
WEIGHT_DECAY = 1e-4  # Weight decay
BATCH_SIZE = 16      # other sizes leave last batch partial

TRAIN_SIZE = int(BATCH_SIZE*18)

PATIENCE = 20
LR_PATIENCE = 5
LR_FACTOR = 0.1

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,15),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.brg

plt.rcParams.update(params) # update rcParams

# %%
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
(modelDir / subDir).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load Data
#
# ### Data Set Information:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this database are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# Attribute Information:
#
# -- All 34 are continuous
# -- The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
# We will model this as two class.

# %%
data_df = pd.read_csv(inpDir/subDir/'ionosphere.data', header = None)
data_df.shape
# Out:
# (351, 35)

# %%
data_df.head()
# Out:
#    0   1        2        3        4        5        6        7        8   \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#         9   ...       25       26       27       28       29       30  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#         31       32       33  34
# 0 -0.54487  0.18641 -0.45300   g
# 1 -0.06288 -0.13738 -0.02447   b
# 2 -0.24180  0.56045 -0.38238   g
# 3  1.00000 -0.32382  1.00000   b
# 4 -0.59573 -0.04608 -0.65697   g
#
# [5 rows x 35 columns]

# %%
X = data_df.drop(data_df.columns[-1], axis = 1).to_numpy()

y = data_df[data_df.columns[-1]].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y,
                                                   train_size = TRAIN_SIZE,
                                                   stratify=y,
                                                   random_state=RANDOM_STATE)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((288, 34), (63, 34), (288,), (63,))

# %%
le = LabelEncoder()

y_train = le.fit_transform(y_train)

y_test = le.transform(y_test)

# %%
class_name = list(le.classes_)
class_name
# Out:
# ['b', 'g']

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %% [markdown]
# ## Converting to Datasets

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train,y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test,y_test))
# Out:
# I0000 00:00:1778583862.000074  121114 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4135 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
## Optimize for performance

train_ds = train_ds.cache()  # Cache first
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

test_ds = test_ds.cache()
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Shuffle and batch the dataset
train_ds = train_ds.shuffle(buffer_size=X_train.shape[0]).batch(BATCH_SIZE)
test_ds = test_ds.shuffle(buffer_size=X_test.shape[0]).batch(BATCH_SIZE)

# %%
for features, labels in train_ds.take(1):
    print (features.shape, labels.shape)
# Out:
# (16, 34) (16,)

# %%
## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model1 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dense (18,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer),

   tf.keras.layers.Dense (10,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dense (2),
    
])

# %%
model1.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])

# %%
history = model1.fit( train_ds,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=test_ds,
                    verbose = 2)
# Out:
# Epoch 1/100
# I0000 00:00:1778583864.236424  121212 service.cc:153] XLA service 0x791fc8031ec0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778583864.236457  121212 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6 (Driver: 13.0.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.19.0)
# I0000 00:00:1778583864.253869  121212 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778583864.366995  121212 cuda_dnn.cc:461] Loaded cuDNN version 91900
# I0000 00:00:1778583864.373023  121212 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1498__.12
# I0000 00:00:1778583866.135245  121212 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 18/18 - 4s - 211ms/step - accuracy: 0.7500 - loss: 0.6484 - val_accuracy: 0.7302 - val_loss: 0.6475
# Epoch 2/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8125 - loss: 0.5494 - val_accuracy: 0.7937 - val_loss: 0.5738
# Epoch 3/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8438 - loss: 0.4787 - val_accuracy: 0.8254 - val_loss: 0.5139
# Epoch 4/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8785 - loss: 0.4197 - val_accuracy: 0.8413 - val_loss: 0.4570
# Epoch 5/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8819 - loss: 0.3703 - val_accuracy: 0.8413 - val_loss: 0.4133
# Epoch 6/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8924 - loss: 0.3288 - val_accuracy: 0.8571 - val_loss: 0.3658
# Epoch 7/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9062 - loss: 0.2916 - val_accuracy: 0.8571 - val_loss: 0.3435
# Epoch 8/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9236 - loss: 0.2603 - val_accuracy: 0.8571 - val_loss: 0.3052
# Epoch 9/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9271 - loss: 0.2349 - val_accuracy: 0.8571 - val_loss: 0.2885
# Epoch 10/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9306 - loss: 0.2086 - val_accuracy: 0.8730 - val_loss: 0.2686
# Epoch 11/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9375 - loss: 0.1892 - val_accuracy: 0.8730 - val_loss: 0.2475
# Epoch 12/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9479 - loss: 0
100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0232 - val_accuracy: 0.9524 - val_loss: 0.1631
# Epoch 44/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9931 - loss: 0.0227 - val_accuracy: 0.9524 - val_loss: 0.1549
# Epoch 45/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9931 - loss: 0.0216 - val_accuracy: 0.9524 - val_loss: 0.1588
# Epoch 46/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0209 - val_accuracy: 0.9524 - val_loss: 0.1566
# Epoch 47/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9931 - loss: 0.0208 - val_accuracy: 0.9365 - val_loss: 0.1627
# Epoch 48/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0195 - val_accuracy: 0.9524 - val_loss: 0.1575
# Epoch 49/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9931 - loss: 0.0189 - val_accuracy: 0.9365 - val_loss: 0.1656
# Epoch 50/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0179 - val_accuracy: 0.9365 - val_loss: 0.1728
# Epoch 51/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0173 - val_accuracy: 0.9365 - val_loss: 0.1665
# Epoch 52/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0165 - val_accuracy: 0.9524 - val_loss: 0.1729
# Epoch 53/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0160 - val_accuracy: 0.9365 - val_loss: 0.1820
# Epoch 54/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0153 - val_accuracy: 0.9524 - val_loss: 0.1721
# Epoch 55/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0144 - val_accuracy: 0.9524 - val_loss: 0.1802
# Epoch 56/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0149 - val_accuracy: 0.9524 - val_loss: 0.1844
# Epoch 57/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0140 - val_accuracy: 0.9524 - val_loss: 0.1949
# Epoch 58/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0134 - val_accuracy: 0.9524 - val_loss: 0.1821
# Epoch 59/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0131 - val_accuracy: 0.9524 - val_loss: 0.1952
# Epoch 60/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0129 - val_accuracy: 0.9524 - val_loss: 0.2010
# Epoch 61/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0127 - val_accuracy: 0.9524 - val_loss: 0.1982
# Epoch 62/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0111 - val_accuracy: 0.9524 - val_loss: 0.1782
# Epoch 63/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0102 - val_accuracy: 0.9524 - val_loss: 0.1915
# Epoch 64/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0097 - val_accuracy: 0.9524 - val_loss: 0.2051
# Epoch 65/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0096 - val_accuracy: 0.9524 - val_loss: 0.2201
# Epoch 66/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0087 - val_accuracy: 0.9524 - val_loss: 0.2258
# Epoch 67/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0095 - val_accuracy: 0.9524 - val_loss: 0.2341
# Epoch 68/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9365 - val_loss: 0.1987
# Epoch 69/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9524 - val_loss: 0.2281
# Epoch 70/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9965 - loss: 0.0082 - val_accuracy: 0.9524 - val_loss: 0.2384
# Epoch 71/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9365 - val_loss: 0.2048
# Epoch 72/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9365 - val_loss: 0.2309
# Epoch 73/100
# 18/18 - 0s - 4ms/step - accuracy: 0.9965 - loss: 0.0070 - val_accuracy: 0.9365 - val_loss: 0.2301
# Epoch 74/100
# 18/18 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9365 - val_loss: 0.2280
# Epoch 75/100
# 18/18 - 0s - 3ms/step - accuracy: 0.9965 - loss: 0.0064 - val_accuracy: 0.9365 - val_loss: 0.2541
# Epoch 76/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9365 - val_loss: 0.2293
# Epoch 77/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9365 - val_loss: 0.2344
# Epoch 78/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9365 - val_loss: 0.2456
# Epoch 79/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9365 - val_loss: 0.2474
# Epoch 80/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9365 - val_loss: 0.2516
# Epoch 81/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9365 - val_loss: 0.2415
# Epoch 82/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9365 - val_loss: 0.2703
# Epoch 83/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9365 - val_loss: 0.2455
# Epoch 84/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9365 - val_loss: 0.2601
# Epoch 85/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9365 - val_loss: 0.2559
# Epoch 86/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9365 - val_loss: 0.2504
# Epoch 87/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9365 - val_loss: 0.2699
# Epoch 88/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9365 - val_loss: 0.2621
# Epoch 89/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9365 - val_loss: 0.2613
# Epoch 90/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9365 - val_loss: 0.2745
# Epoch 91/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9365 - val_loss: 0.2791
# Epoch 92/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9365 - val_loss: 0.2624
# Epoch 93/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9365 - val_loss: 0.2737
# Epoch 94/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9365 - val_loss: 0.2780
# Epoch 95/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9365 - val_loss: 0.2775
# Epoch 96/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9365 - val_loss: 0.2861
# Epoch 97/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9365 - val_loss: 0.2763
# Epoch 98/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9365 - val_loss: 0.2793
# Epoch 99/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9365 - val_loss: 0.2866
# Epoch 100/100
# 18/18 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9365 - val_loss: 0.2831

# %%
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 26)             │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 18)             │           486 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,826 (18.86 KB)
#  Trainable params: 1,608 (6.28 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,218 (12.57 KB)

# %%
hist_df = pd.DataFrame(history.history)
hist_df.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.750000  0.648399      0.730159  0.647518
# 1  0.812500  0.549401      0.793651  0.573837
# 2  0.843750  0.478749      0.825397  0.513898
# 3  0.878472  0.419704      0.841270  0.457041
# 4  0.881944  0.370318      0.841270  0.413336

# %%
fn_plot_tf_hist(hist_df)

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 31  0.989583  0.037908      0.952381  0.140914

# %%
proba_model1 = tf.keras.Sequential([model1,
                                   tf.keras.layers.Softmax()])

y_pred = proba_model1(X_test)

# %%
class_name
# Out:
# ['b', 'g']

# %%
fn_plot_confusion_matrix(y_test, y_pred.numpy().argmax(axis = 1), labels=class_name)

# %% [markdown]
# ## L2 Regularizer
#
# L2 regularization (also called weight decay) adds a penalty term to the loss function:
#
# **Loss = original_loss + $\lambda \cdot \sum(w^2)$**
#
# This encourages weights to be small, preventing any single feature from dominating and reducing overfitting.

# %%
## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

regularizer = tf.keras.regularizers.L2(0.05)

model2 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( shape =( 34, ) ),

    tf.keras.layers.Dense (26,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer,
                           kernel_regularizer = regularizer),   # ---- add L2 Regularizer
    
    tf.keras.layers.Dense (18,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer,
                           kernel_regularizer = regularizer),   # ---- add L2 Regularizer

   tf.keras.layers.Dense (10,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer,
                           kernel_regularizer = regularizer),   # ---- add L2 Regularizer
    
    tf.keras.layers.Dense (2),
    
])

model2.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])


history = model2.fit(train_ds,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=test_ds,
                    verbose = 2)

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# I0000 00:00:1778583871.937210  121211 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data
100
# 18/18 - 0s - 2ms/step - accuracy: 0.9688 - loss: 0.2985 - val_accuracy: 0.9048 - val_loss: 0.3642
# Epoch 70/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2974 - val_accuracy: 0.9365 - val_loss: 0.3548
# Epoch 71/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9688 - loss: 0.2966 - val_accuracy: 0.9206 - val_loss: 0.3533
# Epoch 72/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9653 - loss: 0.3014 - val_accuracy: 0.9365 - val_loss: 0.3540
# Epoch 73/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.2958 - val_accuracy: 0.9206 - val_loss: 0.3535
# Epoch 74/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9688 - loss: 0.2912 - val_accuracy: 0.9206 - val_loss: 0.3525
# Epoch 75/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2900 - val_accuracy: 0.9365 - val_loss: 0.3515
# Epoch 76/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9688 - loss: 0.2902 - val_accuracy: 0.9048 - val_loss: 0.3560
# Epoch 77/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2889 - val_accuracy: 0.9365 - val_loss: 0.3479
# Epoch 78/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.2878 - val_accuracy: 0.9365 - val_loss: 0.3492
# Epoch 79/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2852 - val_accuracy: 0.9365 - val_loss: 0.3513
# Epoch 80/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2850 - val_accuracy: 0.9365 - val_loss: 0.3444
# Epoch 81/100
# 18/18 - 0s - 3ms/step - accuracy: 0.9688 - loss: 0.2850 - val_accuracy: 0.9365 - val_loss: 0.3469
# Epoch 82/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2849 - val_accuracy: 0.9365 - val_loss: 0.3456
# Epoch 83/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.2855 - val_accuracy: 0.9365 - val_loss: 0.3396
# Epoch 84/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.2829 - val_accuracy: 0.9365 - val_loss: 0.3466
# Epoch 85/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.2796 - val_accuracy: 0.9365 - val_loss: 0.3433
# Epoch 86/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9688 - loss: 0.2810 - val_accuracy: 0.9365 - val_loss: 0.3428
# Epoch 87/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2814 - val_accuracy: 0.9365 - val_loss: 0.3441
# Epoch 88/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9618 - loss: 0.2825 - val_accuracy: 0.9365 - val_loss: 0.3396
# Epoch 89/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9688 - loss: 0.2801 - val_accuracy: 0.9365 - val_loss: 0.3455
# Epoch 90/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2765 - val_accuracy: 0.9365 - val_loss: 0.3354
# Epoch 91/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2753 - val_accuracy: 0.9365 - val_loss: 0.3394
# Epoch 92/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2781 - val_accuracy: 0.9365 - val_loss: 0.3453
# Epoch 93/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9653 - loss: 0.2781 - val_accuracy: 0.9365 - val_loss: 0.3392
# Epoch 94/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2732 - val_accuracy: 0.9365 - val_loss: 0.3372
# Epoch 95/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2716 - val_accuracy: 0.9365 - val_loss: 0.3375
# Epoch 96/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.2726 - val_accuracy: 0.9365 - val_loss: 0.3338
# Epoch 97/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.2692 - val_accuracy: 0.9365 - val_loss: 0.3370
# Epoch 98/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.2710 - val_accuracy: 0.9365 - val_loss: 0.3377
# Epoch 99/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2697 - val_accuracy: 0.9365 - val_loss: 0.3347
# Epoch 100/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.2693 - val_accuracy: 0.9365 - val_loss: 0.3347

# %%
fn_plot_tf_hist(hist_df)

# %% [markdown]
# ## Batch Normalization
# - Normalizes layer outputs to have mean ~0, variance ~1
# - Allows higher learning rates
# - Reduces internal covariate shift
# - Has a slight regularization effect

# %%
## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model3 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    
    tf.keras.layers.Dense (18,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    tf.keras.layers.Dense (10,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    tf.keras.layers.Dense (2),
    
])


model3.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])


history = model3.fit(train_ds, 
                     epochs=EPOCHS,
                     batch_size = BATCH_SIZE,
                     validation_data=test_ds,
                     verbose = 2)

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# I0000 00:00:1778583878.761475  121214 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_28974__.30
# 18/18 - 4s - 233ms/step - accuracy: 0.6944 - loss: 0.6959 - val_accuracy: 0.5714 - val_loss: 0.6371
# Epoch 2/100
# 18/18 - 0s - 2ms/step - accuracy: 0.7535 - loss: 0.4952 - val_accuracy: 0.7937 - val_loss: 0.5211
# Epoch 3/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8368 - loss: 0.4292 - val_accuracy: 0.8889 - val_loss: 0.4294
# Epoch 4/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8507 - loss: 0.3729 - val_accuracy: 0.9048 - val_loss: 0.3740
# Epoch 5/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8785 - loss: 0.3126 - val_accuracy: 0.9524 - val_loss: 0.3352
# Epoch 6/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8715 - loss: 0.3186 - val_accuracy: 0.9365 - val_loss: 0.3023
# Epoch 7/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8715 - loss: 0.2983 - val_accuracy: 0.9365 - val_loss: 0.2761
# Epoch 8/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9132 - loss: 0.2558 - val_accuracy: 0.9365 - val_loss: 0.2491
# Epoch 9/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9062 - loss: 0.2447 - val_accuracy: 0.9365 - val_loss: 0.2285
# Epoch 10/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9132 - loss: 0.2428 - val_accuracy: 0.9365 - val_loss: 0.2032
# Epoch 11/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9201 - loss: 0.2246 - val_accuracy: 0.9524 - val_loss: 0.1839
# Epoch 12/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9097 - loss: 0.2289 - val_accuracy: 0.9524 - val_loss: 0.1738
# Epoch 13/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9340 - loss: 0.2273 - val_accuracy: 0.9524 - val_loss: 0.1580
# Epoch 14/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9340 - loss: 0.1923 - val_accuracy: 0.9524 - val_loss: 0.1469
# Epoch 15/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9062 - loss: 0.2134 - val_accuracy: 0.9524 - val_loss: 0.1366
# Epoch 16/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9340 - loss: 0.1727 - val_accuracy: 0.9683 - val_loss: 0.1326
# Epoch 17/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9236 - loss: 0.1949 - val_accuracy: 0.9365 - val_loss: 0.1338
# Epoch 18/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9375 - loss: 0.1897 - val_accuracy: 0.9683 - val_loss: 0.1211
# Epoch 19/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9375 - loss: 0.1821 - val_accuracy: 0.9841 - val_loss: 0.1084
# Epoch 20/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9375 - loss: 0.1681 - val_accuracy: 0.9841 - val_loss: 0.1069
# Epoch 21/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9583 - loss: 0.1578 - val_accuracy: 0.9841 - val_loss: 0.1012
# Epoch 22/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9479 - loss: 0.1588 - val_accuracy: 0.9841 - val_loss: 0.0959
# Epoch 23/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9583 - loss: 0.1101 - val_accuracy: 0.9683 - val_loss: 0.0996
# Epoch 24/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9306 - loss: 0.1828 - val_accuracy: 1.0000 - val_loss: 0.0904
# Epoch 25/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9514 - loss: 0.1325 - val_accuracy: 1.0000 - val_loss: 0.0891
# Epoch 26/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9514 - loss: 0.1327 - val_accuracy: 1.0000 - val_loss: 0.0828
# Epoch 27/100
# 18/18 - 0s - 2ms/step - accuracy: 0.
100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.0765 - val_accuracy: 0.9841 - val_loss: 0.0633

# %%
fn_plot_tf_hist(hist_df)

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 99  0.972222  0.076494      0.984127  0.063272

# %% [markdown]
# ## DROP OUTS

# %%
rate1 = 0.2
rate2 = 0.3
rate3 = 0.4

## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model4 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           activation = 'relu',
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dropout(rate1 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (18,
                           activation = 'relu',
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dropout(rate2 , seed = RANDOM_STATE),

    tf.keras.layers.Dense (10,
                           activation = 'relu',
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dropout(rate3 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (2),
    
])


model4.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])


history = model4.fit(train_ds,
                     epochs=EPOCHS,
                     batch_size = BATCH_SIZE,
                     validation_data=test_ds,
                     verbose = 2)

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# I0000 00:00:1778583886.040742  121213 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_42312__.15
# 18/18 - 3s - 177ms/step - accuracy: 0.3819 - loss: 0.7905 - val_accuracy: 0.3968 - val_loss: 0.6816
# Epoch 2/100
# 18/18 - 0s - 2ms/step - accuracy: 0.4618 - loss: 0.7240 - val_accuracy: 0.7937 - val_loss: 0.6324
# Epoch 3/100
# 18/18 - 0s - 2ms/step - accuracy: 0.6354 - loss: 0.6480 - val_accuracy: 0.8095 - val_loss: 0.6051
# Epoch 4/100
# 18/18 - 0s - 2ms/step - accuracy: 0.6528 - loss: 0.6361 - val_accuracy: 0.8254 - val_loss: 0.5832
# Epoch 5/100
# 18/18 - 0s - 2ms/step - accuracy: 0.7639 - loss: 0.5859 - val_accuracy: 0.8571 - val_loss: 0.5574
# Epoch 6/100
# 18/18 - 0s - 2ms/step - accuracy: 0.7569 - loss: 0.5775 - val_accuracy: 0.8730 - val_loss: 0.5245
# Epoch 7/100
# 18/18 - 0s - 2ms/step - accuracy: 0.7917 - loss: 0.5469 - val_accuracy: 0.8889 - val_loss: 0.4864
# Epoch 8/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8160 - loss: 0.4988 - val_accuracy: 0.8730 - val_loss: 0.4505
# Epoch 9/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8333 - loss: 0.4855 - val_accuracy: 0.8889 - val_loss: 0.4091
# Epoch 10/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8507 - loss: 0.4587 - val_accuracy: 0.8889 - val_loss: 0.3785
# Epoch 11/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8576 - loss: 0.4393 - val_accuracy: 0.8889 - val_loss: 0.3508
# Epoch 12/100
# 18/18 - 0s - 2ms/step - accuracy: 0.8785 - loss: 0.4023 - val_accuracy: 0.9048 - val_loss: 0.3252
# Epoch 13/100
# 18/18 - 0s - 2ms/step - accuracy: 0.
100
# 18/18 - 0s - 2ms/step - accuracy: 0.9861 - loss: 0.0701 - val_accuracy: 0.9524 - val_loss: 0.1179
# Epoch 84/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.0906 - val_accuracy: 0.9524 - val_loss: 0.1011
# Epoch 85/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.0734 - val_accuracy: 0.9365 - val_loss: 0.0975
# Epoch 86/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9583 - loss: 0.0916 - val_accuracy: 0.9524 - val_loss: 0.1137
# Epoch 87/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.0739 - val_accuracy: 0.9683 - val_loss: 0.1209
# Epoch 88/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9757 - loss: 0.0782 - val_accuracy: 0.9683 - val_loss: 0.1101
# Epoch 89/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9861 - loss: 0.0479 - val_accuracy: 0.9683 - val_loss: 0.1059
# Epoch 90/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9931 - loss: 0.0498 - val_accuracy: 0.9683 - val_loss: 0.1192
# Epoch 91/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.0727 - val_accuracy: 0.9683 - val_loss: 0.1224
# Epoch 92/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9861 - loss: 0.0599 - val_accuracy: 0.9683 - val_loss: 0.1138
# Epoch 93/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.0616 - val_accuracy: 0.9841 - val_loss: 0.1042
# Epoch 94/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.0718 - val_accuracy: 0.9841 - val_loss: 0.0820
# Epoch 95/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9826 - loss: 0.0557 - val_accuracy: 0.9841 - val_loss: 0.0785
# Epoch 96/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9896 - loss: 0.0451 - val_accuracy: 0.9683 - val_loss: 0.0886
# Epoch 97/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9861 - loss: 0.0523 - val_accuracy: 0.9524 - val_loss: 0.1011
# Epoch 98/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9792 - loss: 0.0496 - val_accuracy: 0.9524 - val_loss: 0.1130
# Epoch 99/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9931 - loss: 0.0349 - val_accuracy: 0.9683 - val_loss: 0.1194
# Epoch 100/100
# 18/18 - 0s - 2ms/step - accuracy: 0.9722 - loss: 0.0675 - val_accuracy: 0.9365 - val_loss: 0.1101

# %%
fn_plot_tf_hist(hist_df)

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 94  0.982639  0.055687      0.984127  0.078522

# %% [markdown]
# ### All In

# %%
rate1 = 0.05
rate2 = 0.15
rate3 = 0.25

## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.AdamW(learning_rate=ALPHA, weight_decay=WEIGHT_DECAY) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

# Suppressing regularization
#regularizer = tf.keras.regularizers.L2(0.05)
regularizer = None

model = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    tf.keras.layers.Dropout(rate1 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (18,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    tf.keras.layers.Dropout(rate2 , seed = RANDOM_STATE),

    tf.keras.layers.Dense (10,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    tf.keras.layers.Dropout(rate3 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (2),
    
])

model.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])

# %%
checkpoint_filepath = modelDir / subDir / 'all_in.keras'

# Model is saved at the end of every epoch, if it's the best seen so far.
chkpt_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    verbose = 2,
    save_best_only=True
)

es_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss',
    patience=PATIENCE,
    mode='auto',
    verbose = 2,
    baseline =None,
    restore_best_weights=True)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=2,
    mode='auto',
    min_lr=0.00001)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logDir)

# %%
history = model.fit(train_ds, 
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=test_ds,
                    verbose = 2,
                    callbacks = [es_callback, 
                                 chkpt_callback, 
                                 lr_callback, 
                                 tensorboard_callback])

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# I0000 00:00:1778583893.757012  121212 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_57013__.33
# Epoch 1: val_loss improved from None to 0.73340, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 1: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 5s - 276ms/step - accuracy: 0.4722 - loss: 0.9945 - val_accuracy: 0.3651 - val_loss: 0.7334 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.73340 to 0.61782, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 2: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.5278 - loss: 0.8371 - val_accuracy: 0.5079 - val_loss: 0.6178 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.61782 to 0.54073, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 3: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.5764 - loss: 0.7424 - val_accuracy: 0.7619 - val_loss: 0.5407 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.54073 to 0.48472, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 4: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.6944 - loss: 0.6212 - val_accuracy: 0.8889 - val_loss: 0.4847 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.48472 to 0.44596, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 5: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.7396 - loss: 0.5412 - val_accuracy: 0.9365 - val_loss: 0.4460 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.44596 to 0.41271, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 6: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.7708 - loss: 0.5208 - val_accuracy: 0.9683 - val_loss: 0.4127 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.41271 to 0.38480, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 7: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8056 - loss: 0.4870 - val_accuracy: 0.9524 - val_loss: 0.3848 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.38480 to 0.36555, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 8: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8229 - loss: 0.4615 - val_accuracy: 0.9524 - val_loss: 0.3655 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.36555 to 0.34623, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 9: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8194 - loss: 0.4662 - val_accuracy: 0.9365 - val_loss: 0.3462 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.34623 to 0.32816, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 10: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8299 - loss: 0.4474 - val_accuracy: 0.9365 - val_loss: 0.3282 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.32816 to 0.31252, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 11: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8750 - loss: 0.3630 - val_accuracy: 0.9206 - val_loss: 0.3125 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.31252 to 0.29444, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 12: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8785 - loss: 0.3811 - val_accuracy: 0.9206 - val_loss: 0.2944 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.29444 to 0.28203, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 13: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8646 - loss: 0.3749 - val_accuracy: 0.9365 - val_loss: 0.2820 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.28203 to 0.26866, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 14: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8681 - loss: 0.3747 - val_accuracy: 0.9365 - val_loss: 0.2687 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.26866 to 0.25790, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 15: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8750 - loss: 0.3270 - val_accuracy: 0.9365 - val_loss: 0.2579 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.25790 to 0.25086, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 16: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8819 - loss: 0.3262 - val_accuracy: 0.9365 - val_loss: 0.2509 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.25086 to 0.24006, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 17: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8924 - loss: 0.3283 - val_accuracy: 0.9365 - val_loss: 0.2401 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.24006 to 0.22898, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 18: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8819 - loss: 0.3308 - val_accuracy: 0.9365 - val_loss: 0.2290 - learning_rate: 0.0010
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.22898 to 0.22257, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 19: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8993 - loss: 0.2945 - val_accuracy: 0.9365 - val_loss: 0.2226 - learning_rate: 0.0010
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.22257 to 0.21935, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 20: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8889 - loss: 0.2842 - val_accuracy: 0.9365 - val_loss: 0.2193 - learning_rate: 0.0010
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.21935 to 0.21058, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 21: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8958 - loss: 0.2864 - val_accuracy: 0.9365 - val_loss: 0.2106 - learning_rate: 0.0010
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.21058 to 0.20323, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 22: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8889 - loss: 0.3118 - val_accuracy: 0.9365 - val_loss: 0.2032 - learning_rate: 0.0010
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.20323 to 0.19667, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 23: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8889 - loss: 0.2784 - val_accuracy: 0.9365 - val_loss: 0.1967 - learning_rate: 0.0010
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.19667 to 0.19049, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 24: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8924 - loss: 0.2846 - val_accuracy: 0.9365 - val_loss: 0.1905 - learning_rate: 0.0010
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.19049 to 0.18397, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 25: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9062 - loss: 0.2695 - val_accuracy: 0.9365 - val_loss: 0.1840 - learning_rate: 0.0010
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.18397 to 0.17525, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 26: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.8958 - loss: 0.2582 - val_accuracy: 0.9524 - val_loss: 0.1752 - learning_rate: 0.0010
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.17525 to 0.16681, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 27: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9201 - loss: 0.2399 - val_accuracy: 0.9524 - val_loss: 0.1668 - learning_rate: 0.0010
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.16681
# 18/18 - 0s - 3ms/step - accuracy: 0.9132 - loss: 0.2644 - val_accuracy: 0.9524 - val_loss: 0.1673 - learning_rate: 0.0010
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.16681
# 18/18 - 0s - 3ms/step - accuracy: 0.9306 - loss: 0.2087 - val_accuracy: 0.9365 - val_loss: 0.1673 - learning_rate: 0.0010
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.16681
# 18/18 - 0s - 3ms/step - accuracy: 0.9236 - loss: 0.2236 - val_accuracy: 0.9524 - val_loss: 0.1696 - learning_rate: 0.0010
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.16681 to 0.15640, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 31: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9132 - loss: 0.2616 - val_accuracy: 0.9524 - val_loss: 0.1564 - learning_rate: 0.0010
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.15640 to 0.15211, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 32: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 6ms/step - accuracy: 0.8924 - loss: 0.2891 - val_accuracy: 0.9524 - val_loss: 0.1521 - learning_rate: 0.0010
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.15211 to 0.15202, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 33: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 6ms/step - accuracy: 0.9479 - loss: 0.1906 - val_accuracy: 0.9524 - val_loss: 0.1520 - learning_rate: 0.0010
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.15202 to 0.14019, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 34: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 6ms/step - accuracy: 0.9167 - loss: 0.2245 - val_accuracy: 0.9683 - val_loss: 0.1402 - learning_rate: 0.0010
# Epoch 35/100
#
# Epoch 35: val_loss improved from 0.14019 to 0.13808, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 35: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9479 - loss: 0.1960 - val_accuracy: 0.9683 - val_loss: 0.1381 - learning_rate: 0.0010
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.13808
# 18/18 - 0s - 3ms/step - accuracy: 0.9062 - loss: 0.2626 - val_accuracy: 0.9683 - val_loss: 0.1390 - learning_rate: 0.0010
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.13808
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1830 - val_accuracy: 0.9524 - val_loss: 0.1437 - learning_rate: 0.0010
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.13808 to 0.13408, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 38: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9618 - loss: 0.1837 - val_accuracy: 0.9524 - val_loss: 0.1341 - learning_rate: 0.0010
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.13408
# 18/18 - 0s - 3ms/step - accuracy: 0.9236 - loss: 0.1965 - val_accuracy: 0.9524 - val_loss: 0.1353 - learning_rate: 0.0010
# Epoch 40/100
#
# Epoch 40: val_loss improved from 0.13408 to 0.12909, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 40: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9306 - loss: 0.1803 - val_accuracy: 0.9524 - val_loss: 0.1291 - learning_rate: 0.0010
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.12909 to 0.12718, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 41: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9167 - loss: 0.2652 - val_accuracy: 0.9524 - val_loss: 0.1272 - learning_rate: 0.0010
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.12718
# 18/18 - 0s - 3ms/step - accuracy: 0.9375 - loss: 0.1682 - val_accuracy: 0.9524 - val_loss: 0.1340 - learning_rate: 0.0010
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.12718
# 18/18 - 0s - 3ms/step - accuracy: 0.9340 - loss: 0.1827 - val_accuracy: 0.9524 - val_loss: 0.1317 - learning_rate: 0.0010
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.12718
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1643 - val_accuracy: 0.9524 - val_loss: 0.1397 - learning_rate: 0.0010
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.12718
# 18/18 - 0s - 3ms/step - accuracy: 0.8889 - loss: 0.2457 - val_accuracy: 0.9524 - val_loss: 0.1298 - learning_rate: 0.0010
# Epoch 46/100
#
# Epoch 46: val_loss improved from 0.12718 to 0.11447, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 46: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9549 - loss: 0.1469 - val_accuracy: 0.9683 - val_loss: 0.1145 - learning_rate: 0.0010
# Epoch 47/100
#
# Epoch 47: val_loss improved from 0.11447 to 0.10883, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 47: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9410 - loss: 0.1517 - val_accuracy: 0.9683 - val_loss: 0.1088 - learning_rate: 0.0010
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.10883
# 18/18 - 0s - 3ms/step - accuracy: 0.9167 - loss: 0.2446 - val_accuracy: 0.9524 - val_loss: 0.1201 - learning_rate: 0.0010
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.10883 to 0.10608, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 49: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9375 - loss: 0.1671 - val_accuracy: 0.9524 - val_loss: 0.1061 - learning_rate: 0.0010
# Epoch 50/100
#
# Epoch 50: val_loss improved from 0.10608 to 0.10350, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 50: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9236 - loss: 0.2123 - val_accuracy: 0.9524 - val_loss: 0.1035 - learning_rate: 0.0010
# Epoch 51/100
#
# Epoch 51: val_loss improved from 0.10350 to 0.09747, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 51: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9340 - loss: 0.1809 - val_accuracy: 0.9683 - val_loss: 0.0975 - learning_rate: 0.0010
# Epoch 52/100
#
# Epoch 52: val_loss improved from 0.09747 to 0.09682, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 52: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9236 - loss: 0.1937 - val_accuracy: 0.9683 - val_loss: 0.0968 - learning_rate: 0.0010
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.09682
# 18/18 - 0s - 3ms/step - accuracy: 0.9375 - loss: 0.1818 - val_accuracy: 0.9683 - val_loss: 0.0997 - learning_rate: 0.0010
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.09682
# 18/18 - 0s - 3ms/step - accuracy: 0.9514 - loss: 0.1565 - val_accuracy: 0.9683 - val_loss: 0.0970 - learning_rate: 0.0010
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.09682
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1566 - val_accuracy: 0.9683 - val_loss: 0.1007 - learning_rate: 0.0010
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.09682
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1736 - val_accuracy: 0.9683 - val_loss: 0.0983 - learning_rate: 0.0010
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.09682
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 18/18 - 0s - 3ms/step - accuracy: 0.9340 - loss: 0.1655 - val_accuracy: 0.9683 - val_loss: 0.0986 - learning_rate: 0.0010
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.09682
# 18/18 - 0s - 3ms/step - accuracy: 0.9410 - loss: 0.1719 - val_accuracy: 0.9683 - val_loss: 0.0970 - learning_rate: 1.0000e-04
# Epoch 59/100
#
# Epoch 59: val_loss improved from 0.09682 to 0.09564, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 59: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9479 - loss: 0.1685 - val_accuracy: 0.9683 - val_loss: 0.0956 - learning_rate: 1.0000e-04
# Epoch 60/100
#
# Epoch 60: val_loss improved from 0.09564 to 0.09474, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 60: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9722 - loss: 0.1367 - val_accuracy: 0.9683 - val_loss: 0.0947 - learning_rate: 1.0000e-04
# Epoch 61/100
#
# Epoch 61: val_loss improved from 0.09474 to 0.09372, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 61: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9444 - loss: 0.1360 - val_accuracy: 0.9683 - val_loss: 0.0937 - learning_rate: 1.0000e-04
# Epoch 62/100
#
# Epoch 62: val_loss improved from 0.09372 to 0.09280, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 62: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9306 - loss: 0.2045 - val_accuracy: 0.9683 - val_loss: 0.0928 - learning_rate: 1.0000e-04
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.09280
# 18/18 - 0s - 3ms/step - accuracy: 0.9549 - loss: 0.1356 - val_accuracy: 0.9683 - val_loss: 0.0929 - learning_rate: 1.0000e-04
# Epoch 64/100
#
# Epoch 64: val_loss improved from 0.09280 to 0.09263, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 64: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9201 - loss: 0.2068 - val_accuracy: 0.9683 - val_loss: 0.0926 - learning_rate: 1.0000e-04
# Epoch 65/100
#
# Epoch 65: val_loss improved from 0.09263 to 0.09254, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 65: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9201 - loss: 0.2183 - val_accuracy: 0.9683 - val_loss: 0.0925 - learning_rate: 1.0000e-04
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.09254
# 18/18 - 0s - 2ms/step - accuracy: 0.9444 - loss: 0.1529 - val_accuracy: 0.9683 - val_loss: 0.0932 - learning_rate: 1.0000e-04
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.09254
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1516 - val_accuracy: 0.9683 - val_loss: 0.0928 - learning_rate: 1.0000e-04
# Epoch 68/100
#
# Epoch 68: val_loss improved from 0.09254 to 0.09235, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 68: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 4ms/step - accuracy: 0.9514 - loss: 0.1402 - val_accuracy: 0.9683 - val_loss: 0.0923 - learning_rate: 1.0000e-04
# Epoch 69/100
#
# Epoch 69: val_loss improved from 0.09235 to 0.09128, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 69: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9549 - loss: 0.1316 - val_accuracy: 0.9683 - val_loss: 0.0913 - learning_rate: 1.0000e-04
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.09128
# 18/18 - 0s - 3ms/step - accuracy: 0.9444 - loss: 0.1575 - val_accuracy: 0.9683 - val_loss: 0.0914 - learning_rate: 1.0000e-04
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.09128
# 18/18 - 0s - 3ms/step - accuracy: 0.9618 - loss: 0.1350 - val_accuracy: 0.9683 - val_loss: 0.0915 - learning_rate: 1.0000e-04
# Epoch 72/100
#
# Epoch 72: val_loss improved from 0.09128 to 0.08962, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 72: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9549 - loss: 0.1375 - val_accuracy: 0.9683 - val_loss: 0.0896 - learning_rate: 1.0000e-04
# Epoch 73/100
#
# Epoch 73: val_loss improved from 0.08962 to 0.08876, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 73: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9444 - loss: 0.1461 - val_accuracy: 0.9683 - val_loss: 0.0888 - learning_rate: 1.0000e-04
# Epoch 74/100
#
# Epoch 74: val_loss improved from 0.08876 to 0.08822, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 74: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9306 - loss: 0.2063 - val_accuracy: 0.9683 - val_loss: 0.0882 - learning_rate: 1.0000e-04
# Epoch 75/100
#
# Epoch 75: val_loss improved from 0.08822 to 0.08796, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 75: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9375 - loss: 0.1825 - val_accuracy: 0.9683 - val_loss: 0.0880 - learning_rate: 1.0000e-04
# Epoch 76/100
#
# Epoch 76: val_loss improved from 0.08796 to 0.08795, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 76: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9410 - loss: 0.1551 - val_accuracy: 0.9683 - val_loss: 0.0880 - learning_rate: 1.0000e-04
# Epoch 77/100
#
# Epoch 77: val_loss improved from 0.08795 to 0.08742, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 77: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9618 - loss: 0.1311 - val_accuracy: 0.9683 - val_loss: 0.0874 - learning_rate: 1.0000e-04
# Epoch 78/100
#
# Epoch 78: val_loss improved from 0.08742 to 0.08681, saving model to ../models/ionosphere/all_in.keras
#
# Epoch 78: finished saving model to ../models/ionosphere/all_in.keras
# 18/18 - 0s - 5ms/step - accuracy: 0.9583 - loss: 0.1522 - val_accuracy: 0.9683 - val_loss: 0.0868 - learning_rate: 1.0000e-04
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1706 - val_accuracy: 0.9683 - val_loss: 0.0878 - learning_rate: 1.0000e-04
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1548 - val_accuracy: 0.9683 - val_loss: 0.0881 - learning_rate: 1.0000e-04
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9514 - loss: 0.1679 - val_accuracy: 0.9683 - val_loss: 0.0876 - learning_rate: 1.0000e-04
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9618 - loss: 0.1316 - val_accuracy: 0.9683 - val_loss: 0.0883 - learning_rate: 1.0000e-04
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.08681
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 18/18 - 0s - 3ms/step - accuracy: 0.9306 - loss: 0.1911 - val_accuracy: 0.9683 - val_loss: 0.0888 - learning_rate: 1.0000e-04
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9514 - loss: 0.1463 - val_accuracy: 0.9683 - val_loss: 0.0888 - learning_rate: 1.0000e-05
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9410 - loss: 0.1759 - val_accuracy: 0.9683 - val_loss: 0.0881 - learning_rate: 1.0000e-05
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9375 - loss: 0.1857 - val_accuracy: 0.9683 - val_loss: 0.0875 - learning_rate: 1.0000e-05
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9236 - loss: 0.1936 - val_accuracy: 0.9683 - val_loss: 0.0884 - learning_rate: 1.0000e-05
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.08681
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1e-05.
# 18/18 - 0s - 3ms/step - accuracy: 0.9549 - loss: 0.1592 - val_accuracy: 0.9683 - val_loss: 0.0877 - learning_rate: 1.0000e-05
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9514 - loss: 0.1218 - val_accuracy: 0.9683 - val_loss: 0.0883 - learning_rate: 1.0000e-05
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9514 - loss: 0.1566 - val_accuracy: 0.9683 - val_loss: 0.0887 - learning_rate: 1.0000e-05
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9583 - loss: 0.1216 - val_accuracy: 0.9683 - val_loss: 0.0887 - learning_rate: 1.0000e-05
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9375 - loss: 0.1568 - val_accuracy: 0.9683 - val_loss: 0.0886 - learning_rate: 1.0000e-05
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9479 - loss: 0.1536 - val_accuracy: 0.9683 - val_loss: 0.0881 - learning_rate: 1.0000e-05
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9444 - loss: 0.1426 - val_accuracy: 0.9683 - val_loss: 0.0883 - learning_rate: 1.0000e-05
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9410 - loss: 0.1701 - val_accuracy: 0.9683 - val_loss: 0.0880 - learning_rate: 1.0000e-05
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9549 - loss: 0.1516 - val_accuracy: 0.9683 - val_loss: 0.0883 - learning_rate: 1.0000e-05
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9410 - loss: 0.1561 - val_accuracy: 0.9683 - val_loss: 0.0889 - learning_rate: 1.0000e-05
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.08681
# 18/18 - 0s - 3ms/step - accuracy: 0.9410 - loss: 0.1543 - val_accuracy: 0.9683 - val_loss: 0.0886 - learning_rate: 1.0000e-05
# Epoch 98: early stopping
# Restoring model weights from the end of the best epoch: 78.

# %%
fn_plot_tf_hist(hist_df)

# %%
loss_dict = model.evaluate(test_ds, verbose=1 , return_dict=True)
loss_dict
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.0868
# {'accuracy': 0.9682539701461792, 'loss': 0.08680519461631775}

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 77  0.958333  0.152239      0.968254  0.086805         0.0001

# %%
del model
del model1
del model2
del model3
del model4

# %% [markdown]
# ## Save Complete Model

# %%
# Load the best model
model = tf.keras.models.load_model(checkpoint_filepath)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                │ (None, 26)             │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 26)             │           104 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 26)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 26)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 18)             │           486 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 18)             │            72 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 18)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 18)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 10)             │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 10)             │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,258 (20.54 KB)
#  Trainable params: 1,716 (6.70 KB)
#  Non-trainable params: 108 (432.00 B)
#  Optimizer params: 3,434 (13.42 KB)

# %%
res = model.evaluate(test_ds, verbose=2, return_dict=True)

res['accuracy']
# Out:
# 4/4 - 1s - 229ms/step - accuracy: 0.9683 - loss: 0.0868
# 0.9682539701461792

# %% [markdown]
# ## Summary: Regularization Techniques Comparison
#
# | Technique | Purpose | Key Parameter | Effect |
# |-----------|---------|---------------|--------|
# | L2 Regularization | Penalize large weights | $\lambda$ (lambda) | Smooths decision boundary |
# | Dropout | Randomly disable neurons | dropout rate | Forces redundant learning |
# | Batch Normalization | Normalize layer inputs | momentum | Faster, stable training |
# | Early Stopping | Stop when val loss stops improving | patience | Prevents overfitting |
# | Learning Rate Decay| Reduce when loss stops reducing | patience, LR factor | finetunes LR|
#
# **Best Practice:** Combine techniques thoughtfully. Too much regularization = underfitting.
