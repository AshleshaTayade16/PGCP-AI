# %%
import plotly.express as px
import pandas as pd

# %%
data={
    "Stage":["visit website", "sign up", "Add to cart", "purchase"],
    "Users":[1000,500,100,50]}
df=pd.DataFrame(data)
df
# Out:
#            Stage  Users
# 0  visit website   1000
# 1        sign up    500
# 2    Add to cart    100
# 3       purchase     50

# %%
fig=px.funnel(df,x="Users",y="Stage")
fig
