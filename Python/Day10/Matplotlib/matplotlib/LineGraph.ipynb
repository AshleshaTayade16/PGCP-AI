# %%
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
year = [1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020, 2025]
p_india = [772647793, 864972221, 960301044, 1057922733, 1154676322, 1243481564, 1328024498, 1402617695, 1463865525]
p_urban = [190321782, 222296728, 255558824, 291350282, 334479406, 380744554, 429069459, 483098640, 542742539]

# %%
plt.plot(year, p_india)
plt.show()

# %%
plt.plot(year, p_india, color = "#F54927", lw=0.8, ls='--', label='Population of India')
plt.xlabel('Year')
plt.ylabel('Population of India')
plt.legend()
plt.title('Population of India over the years')
plt.show()

# %%
plt.plot(year, p_india, color = "#F54927", lw=0.8, ls='--', label='Population of India')
plt.plot(year, p_urban, color = "#27F5E0", lw=0.8, ls='-.', label='Urban Population of India')
plt.xlabel('Year')
plt.ylabel('Population of India')
plt.legend()
plt.title('Population of India Vs Urban Population over the years')
plt.show()

# %%
df = pd.read_csv('Population.csv')
df
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 0   1955  3.877009e+08           2.29%      8284413.0        19.7
# 1   1960  4.359903e+08           2.38%      9657890.0        19.2
# 2   1965  4.901401e+08           2.37%     10829962.0        18.5
# 3   1970  5.458643e+08           2.18%     11144824.0        18.1
# 4   1975  6.113095e+08           2.29%     13089053.0        18.4
# 5   1980  6.873540e+08           2.37%     15208898.0        18.9
# 6   1985  7.726478e+08           2.37%     17058754.0        19.3
# 7   1990  8.649722e+08           2.28%     18464886.0        19.7
# 8   1995  9.603010e+08           2.11%     19065765.0        20.3
# 9   2000  1.057923e+09           1.96%     19524338.0        21.2
# 10  2005  1.154676e+09           1.77%     19350718.0        22.2
# 11  2010  1.243482e+09           1.49%     17761048.0        23.6
# 12  2015  1.328024e+09           1.32%     16908587.0        25.3
# ...

# %%
df.drop(index=[14,15,16], inplace=True)
df
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 0   1955  3.877009e+08           2.29%      8284413.0        19.7
# 1   1960  4.359903e+08           2.38%      9657890.0        19.2
# 2   1965  4.901401e+08           2.37%     10829962.0        18.5
# 3   1970  5.458643e+08           2.18%     11144824.0        18.1
# 4   1975  6.113095e+08           2.29%     13089053.0        18.4
# 5   1980  6.873540e+08           2.37%     15208898.0        18.9
# 6   1985  7.726478e+08           2.37%     17058754.0        19.3
# 7   1990  8.649722e+08           2.28%     18464886.0        19.7
# 8   1995  9.603010e+08           2.11%     19065765.0        20.3
# 9   2000  1.057923e+09           1.96%     19524338.0        21.2
# 10  2005  1.154676e+09           1.77%     19350718.0        22.2
# 11  2010  1.243482e+09           1.49%     17761048.0        23.6
# 12  2015  1.328024e+09           1.32%     16908587.0        25.3
# ...

# %%
plt.plot(df['Year'], df['Population'], color = "#F54927", lw=0.8, ls='--', label='Population of India')
plt.plot(df['Year'], df['Urban Population'], color = "#27F5E0", lw=0.8, ls='-.', label='Urban Population of India')
plt.xlabel('Year')
plt.ylabel('Population of India')
plt.legend()
plt.title('Population of India Vs Urban Population over the years')
plt.show()
