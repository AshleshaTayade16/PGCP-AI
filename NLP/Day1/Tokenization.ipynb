# %%
pip install nltk spacy textblob -U
# Out:
# Requirement already satisfied: nltk in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.8.13)
# Requirement already satisfied: textblob in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.20.0)
# Requirement already satisfied: click in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (0.26.2)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (70.2.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\PGCP-AI\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (26.1.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab') #tokenization
nltk.download('stopwords')   #stopwords
nltk.download('averaged_perceptron_tagger')    #POS Tagging
nltk.download('averaged_perceptron_tagger_eng')    #POS Tagging
nltk.download('punkt')
nltk.download('wordnet')   #wordnet and lemmatization
nltk.download('indian')    #INDIAN POS Tagging
nltk.download('omw-1.4')    #multilinguial wordnet
# Out:
# [nltk_data] Downloading package punkt to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\PGCP-AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\PGCP-AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package indian to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## sample task

# %%
sent="They told that their ages are 24 31 and 29 respectively"
#find the avearge of ages mentioned in this sentense
lst=sent.split(" ")
lst
lst1=[]
for i in range(len(lst)):
    if lst[i].isnumeric():   #isdigit()
        lst1.append(int(lst[i]))
print("Avg: ",sum(lst1)/len(lst1))
ages=[int(i) for i in lst if i.isdigit()]
ages
# Out:
# Avg:  28.0
# [24, 31, 29]

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
sent='''Hello friends! How are you?
Welcome to the world of Python Programming.'''

# %%
print(sent)
# Out:
# Hello friends! How are you?
# Welcome to the world of Python Programming.

# %%
sents= sent_tokenize(sent)

# %%
sents
# Out:
# ['Hello friends!',
#  'How are you?',
#  'Welcome to the world of Python Programming.']

# %%
sents[0]
# Out:
# 'Hello friends!'

# %%
sents[1]
# Out:
# 'How are you?'

# %%
sents[2]
# Out:
# 'Welcome to the world of Python Programming.'

# %%
words=word_tokenize(sent)

# %%
words
# Out:
# ['Hello',
#  'friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming',
#  '.']

# %% [markdown]
# ## Among all tokens, find percentage of punctuations symbols in it

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
count_punct=0
for word in word_tokenize(sent):
    if word in string.punctuation:
        count_punct+=1

# %%
count_punct
# Out:
# 3

# %%
count_punct / len(word_tokenize(sent))*100
# Out:
# 20.0

# %%
sent
# Out:
# 'Hello friends! How are you?\nWelcome to the world of Python Programming.'

# %%
new_str=''
for char in sent:
    if char not in string.punctuation:
        new_str += char
print(new_str)
# Out:
# Hello friends How are you
# Welcome to the world of Python Programming

# %%
str1='''पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]

पुण्यावर राष्ट्रकूट राजघराणे, अहमदनगर सल्तनत, मुघल, आदिल शाही घराणे यांनी राज्य केले आहे. १८ व्या शतकात हे शहर मराठा साम्राज्याचा भाग होते, आणि मराठा साम्राज्याचे पंतप्रधान, पेशव्यांची हे आसन होते.[१८] पाताळेश्वर लेणी, शनिवारवाडा, शिंदे छत्री, विश्रामबाग वाडा यासारख्या अनेक ऐतिहासिक खुणा या कालखंडातील आहेत. वेगवेगळ्या कालखंडातील ऐतिहासिक स्थळे शहरभर पसरलेली आहेत.'''

# %%
print(str1)
# Out:
# पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]
#
# पुण्यावर राष्ट्रकूट राजघराणे, अहमदनगर सल्तनत, मुघल, आदिल शाही घराणे यांनी राज्य केले आहे. १८ व्या शतकात हे शहर मराठा साम्राज्याचा भाग होते, आणि मराठा साम्राज्याचे पंतप्रधान, पेशव्यांची हे आसन होते.[१८] पाताळेश्वर लेणी, शनिवारवाडा, शिंदे छत्री, विश्रामबाग वाडा यासारख्या अनेक ऐतिहासिक खुणा या कालखंडातील आहेत. वेगवेगळ्या कालखंडातील ऐतिहासिक स्थळे शहरभर पसरलेली आहेत.

# %%
word_tokenize(str1)
# Out:
# ['पुणे',
#  'हे',
#  'भारताच्या',
#  'दख्खन',
#  'पठारावरील',
#  'महाराष्ट्राचे',
#  'एक',
#  'महत्त्वाचे',
#  'शहर',
#  'आहे',
#  '.',
#  'पुणे',
#  'जिल्ह्याचे',
#  'आणि',
#  'पुणे',
#  'विभागाचे',
#  'हे',
#  'प्रशासकीय',
#  'मुख्यालय',
#  'आहे',
#  '.',
#  '२०११',
#  'जनगणनेनुसार',
#  ',',
#  'शहराच्या',
#  'हद्दीतील',
#  '३.१',
#  'दशलक्ष',
#  'लोकसंख्येसह',
#  'पुणे',
#  'हे',
#  'भारतातील',
#  'नववे',
#  'सर्वात',
#  'जास्त',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  'महानगर',
#  'प्रदेशातील',
#  '७.२',
#  'दशलक्ष',
#  'रहिवासी',
#  'लोकसंख्या',
#  'आहे',
#  ',',
#  'यानुसार',
#  'ते',
#  'आठवे',
#  'सर्वाधिक',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  '[',
#  '८',
#  ']',
#  'पुणे',
#  'शहर',
#  'पुणे',
#  'महानगर',
#  'प्रदेशाचा',
#  'एक',
#  'भाग',
#  'आहे',
#  '.',
#  '[',
#  '९',
#  ']',
#  'भारतातील',
#  'सर्वात',
#  'मोठ्या',
#  'आयटी',
#  'हबपैकी',
#  'पुणे',
#  'एक',
#  'आहे',
#  '.',
#  '[',
#  '१०',
#  ']',
#  '[',
#  '११',
#  ']',
#  'हे',
#  'भारतातील',
#  'सर्वात',
#  'महत्वाचे',
#  'ऑटोमोबाईल',
#  'आणि',
#  'उत्पादन',
#  'केंद्रांपैकी',
#  'एक',
#  'आहे',
#  '.',
#  'पुणे',
#  'हे',
#  'एक',
#  'विकसनशील',
#  'शहर',
#  'आहे',
#  '.',
#  '[',
#  '१२',
#  ']',
#  'या',
#  'शहराला',
#  'येथील',
#  'उच्च',
#  'प्रतिष्ठित',
#  'शैक्षणिक',
#  'संस्थांमुळे',
#  '``',
#  'पूर्वेकडील',
#  'ऑक्सफर्ड',
#  "''",
#  'म्हणून',
#  'संबोधले',
#  'जाते',
#  '.',
#  '[',
#  '१३',
#  ']',
#  '[',
#  '१४',
#  ']',
#  '[',
#  '१५',
#  ']',
#  '``',
#  'भारतातील',
#  'सर्वात',
#  'राहण्यायोग्य',
#  'शहर',
#  "''",
#  'म्हणून',
#  'अनेक',
#  'वेळा',
#  'पुण्याला',
#  'स्थान',
#  'देण्यात',
#  'आले',
#  'आहे',
#  '.',
#  '[',
#  '१६',
#  ']',
#  '[',
#  '१७',
#  ']',
#  'पुण्यावर',
#  'राष्ट्रकूट',
#  'राजघराणे',
#  ',',
#  'अहमदनगर',
#  'सल्तनत',
#  ',',
#  'मुघल',
#  ',',
#  'आदिल',
#  'शाही',
#  'घराणे',
#  'यांनी',
#  'राज्य',
#  'केले',
#  'आहे',
#  '.',
#  '१८',
#  'व्या',
#  'शतकात',
#  'हे',
#  'शहर',
#  'मराठा',
#  'साम्राज्याचा',
#  'भाग',
#  'होते',
#  ',',
#  'आणि',
#  'मराठा',
#  'साम्राज्याचे',
#  'पंतप्रधान',
#  ',',
#  'पेशव्यांची',
#  'हे',
#  'आसन',
#  'होते',
#  '.',
#  '[',
#  '१८',
#  ']',
#  'पाताळेश्वर',
#  'लेणी',
#  ',',
#  'शनिवारवाडा',
#  ',',
#  'शिंदे',
#  'छत्री',
#  ',',
#  'विश्रामबाग',
#  'वाडा',
#  'यासारख्या',
#  'अनेक',
#  'ऐतिहासिक',
#  'खुणा',
#  'या',
#  'कालखंडातील',
#  'आहेत',
#  '.',
#  'वेगवेगळ्या',
#  'कालखंडातील',
#  'ऐतिहासिक',
#  'स्थळे',
#  'शहरभर',
#  'पसरलेली',
#  'आहेत',
#  '.']

# %%
new_sent='Mrs. Kulkarni got ₹ 12 lakh salary.'

# %%
word_tokenize(new_sent)
# Out:
# ['Mrs.', 'Kulkarni', 'got', '₹', '12', 'lakh', 'salary', '.']

# %% [markdown]
# ## working with Text File

# %%
file = open("mydata.txt", "r")
content = file.read()
print(type(content))
print(content)
file.close()
# Out:
# <class 'str'>
# 12 abcd 15, 10
# 4, 9, 9 and 12 10
# 4.5, 11, 6.3 xyz

# %%
data=word_tokenize(content)
data
# Out:
# ['12',
#  'abcd',
#  '15',
#  ',',
#  '10',
#  '4',
#  ',',
#  '9',
#  ',',
#  '9',
#  'and',
#  '12',
#  '10',
#  '4.5',
#  ',',
#  '11',
#  ',',
#  '6.3',
#  'xyz']

# %%
num=[]
for word in data:
    if not word.isalpha() and word not in string.punctuation:
        num.append(float(word))
num
# Out:
# [12.0, 15.0, 10.0, 4.0, 9.0, 9.0, 12.0, 10.0, 4.5, 11.0, 6.3]

# %%
print(sum(num)/len(num))
# Out:
# 9.345454545454546

# %% [markdown]
# ## white space tokenizer

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
tk=WhitespaceTokenizer()

# %%
sent
# Out:
# 'Hello friends! How are you?\nWelcome to the world of Python Programming.'

# %%
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming.']

# %% [markdown]
# ## space tokenizer

# %%
from nltk.tokenize import SpaceTokenizer

# %%
tk=SpaceTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?\nWelcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming.']

# %%
sent='''Hello friends! How are you?
Welcome\tto the world of Python\tProgramming.'''

# %%
print(sent)
# Out:
# Hello friends! How are you?
# Welcome	to the world of Python	Programming.

# %% [markdown]
# ## Tab tokenizer

# %%
from nltk.tokenize import TabTokenizer

# %%
tk=TabTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello friends! How are you?\nWelcome',
#  'to the world of Python',
#  'Programming.']

# %% [markdown]
# ## split

# %%
sent.split('\t')
# Out:
# ['Hello friends! How are you?\nWelcome',
#  'to the world of Python',
#  'Programming.']

# %% [markdown]
# ## Line Tokenizer

# %%
from nltk.tokenize import LineTokenizer

# %%
tk=LineTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello friends! How are you?',
#  'Welcome\tto the world of Python\tProgramming.']

# %%
sent.split('\n')
# Out:
# ['Hello friends! How are you?',
#  'Welcome\tto the world of Python\tProgramming.']

# %% [markdown]
# ## Multi Word Expression Tokenizer

# %%
from nltk.tokenize import MWETokenizer

# %%
nsent='Chhatrapati Shivaji Maharaj ws founder of Maratha empire'

# %%
word_tokenize(nsent)
# Out:
# ['Chhatrapati',
#  'Shivaji',
#  'Maharaj',
#  'ws',
#  'founder',
#  'of',
#  'Maratha',
#  'empire']

# %%
mwe= MWETokenizer(separator=' ')

# %%
mwe.add_mwe(('Chhatrapati','Shivaji' ))

# %%
mwe.tokenize(word_tokenize(nsent))
# Out:
# ['Chhatrapati Shivaji', 'Maharaj', 'ws', 'founder', 'of', 'Maratha', 'empire']

# %% [markdown]
# ## Tweet Tokenizer

# %%
name="रुचिका गायकवाड "

# %%
name
# Out:
# 'रुचिका गायकवाड '

# %%
name.replace('चि','ची')
# Out:
# 'रुचीका गायकवाड '

# %%
name.startswith('र')
# Out:
# True

# %%
name.split()
# Out:
# ['रुचिका', 'गायकवाड']

# %%
char ='\u0915\u093E'
char
# Out:
# 'का'

# %%
char ='\u0041\u0073'
char
# Out:
# 'As'

# %%
ord('क')
# Out:
# 2325

# %%
chr(2325)
# Out:
# 'क'

# %%
sent='Hello friends!:) How are you? Welcome\tto the world of Python <3Programming.'

# %%
sent
# Out:
# 'Hello friends!:) How are you? Welcome\tto the world of Python <3Programming.'

# %%
from nltk.tokenize import TweetTokenizer

# %%
tk = TweetTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends',
#  '!',
#  ':)',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  '<3',
#  'Programming',
#  '.']

# %%
text='👺'

# %%
print(text)
# Out:
# 👺

# %%
data='Hello friends🦍👽 How are you?💪 Welcome to python programming💻'

# %%
print(data)
# Out:
# Hello friends🦍👽 How are you?💪 Welcome to python programming💻

# %%
word_tokenize(data)
# Out:
# ['Hello',
#  'friends🦍👽',
#  'How',
#  'are',
#  'you',
#  '?',
#  '💪',
#  'Welcome',
#  'to',
#  'python',
#  'programming💻']

# %%
tk.tokenize(data)
# Out:
# ['Hello',
#  'friends',
#  '🦍',
#  '👽',
#  'How',
#  'are',
#  'you',
#  '?',
#  '💪',
#  'Welcome',
#  'to',
#  'python',
#  'programming',
#  '💻']

# %% [markdown]
# ## custom Tokenizer

# %%
import re

# %%
def custom_tokenizer(text):
    return re.split(r"[.,;?!\s]+",text)
text="This is some text with punctuation > Let's tokenize it. Is it ok?"

# %%
custom_tokenizer(text)
# Out:
# ['This',
#  'is',
#  'some',
#  'text',
#  'with',
#  'punctuation',
#  '>',
#  "Let's",
#  'tokenize',
#  'it',
#  'Is',
#  'it',
#  'ok',
#  '']

# %%
class CommaTokenizer:
    def tokenize(self,text):
        return re.split(r"[,\s]+",text)

# %%
tk=CommaTokenizer()

# %%
fruits='apple, banana, cherry, pineapple.'

# %%
tk.tokenize(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple.']
