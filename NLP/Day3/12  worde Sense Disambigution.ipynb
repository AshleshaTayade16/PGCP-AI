# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.wsd import lesk

# %%
sent1 = 'I went to bank to deposit my money.'
sent2 = 'We pitched our tent by the bank of river.'

# %%
sense1 = lesk(word_tokenize(sent1), 'bank', 'n')

# %%
sense2 = lesk(word_tokenize(sent2), 'bank', 'n')

# %%
sense1.definition()
# Out:
# 'a financial institution that accepts deposits and channels the money into lending activities'

# %%
sense2.definition()
# Out:
# 'sloping land (especially the slope beside a body of water)'

# %%
nltk.__version__
# Out:
# '3.9.4'

# %%
# Testing the word 'plant' (Living organism vs. Factory)
test_sent1 = 'The green plant needs sunlight and water to grow.'
test_sent2 = 'The automobile plant manufactures thousands of cars every day.'

# %%
sense3 = lesk(word_tokenize(test_sent1), 'plant', 'n')

# %%
sense3.definition()
# Out:
# 'an actor situated in the audience whose acting is rehearsed but seems spontaneous to the audience'

# %%
sense4 = lesk(word_tokenize(test_sent2), 'plant', 'n')

# %%
sense4.definition()
# Out:
# '(botany) a living organism lacking the power of locomotion'

# %%
sent5 = 'The small bat flew out of the dark cave and into the night sky.'
sent6 = 'The cricket player swung the wooden bat and hit a massive six.'

# %%
sense5 = lesk(word_tokenize(sent5), 'bat', 'n')
sense6 = lesk(word_tokenize(sent6), 'bat', 'n')

# %%
sense5.definition()
# Out:
# 'nocturnal mouselike mammal with forelimbs modified to form membranous wings and anatomical adaptations for echolocation by which they navigate'

# %%
sense6.definition()
# Out:
# '(baseball) a turn trying to get a hit'
