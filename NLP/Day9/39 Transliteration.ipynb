# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

# %%
# text="AshleShaa taayaDe"
# text="ruchIkaa gayakavaaDa"
#text

# %%
ttext=transliterate(text,sanscript.ITRANS, sanscript.DEVANAGARI)

# %%
ttext
# Out:
# 'आश्लेषा तायडे'

# %%
ttext=transliterate(text,sanscript.ITRANS, sanscript.TAMIL)
ttext
# Out:
# 'ஆஶ்லேஷா தாயடே'

# %%
ttext=transliterate(text,sanscript.ITRANS, sanscript.BENGALI)
ttext
# Out:
# 'আশ্লেষা তাযডে'
