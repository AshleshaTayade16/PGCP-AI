# %%
import cv2

# %%
img_cv=cv2.imread('D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\Dog1.png')

# %%
type(img_cv)
# Out:
# numpy.ndarray

# %%
img_cv.shape
# Out:
# (675, 1200, 3)

# %%
img_cv
# Out:
# array([[[ 12,  31,  44],
#         [ 12,  31,  44],
#         [ 12,  31,  44],
#         ...,
#         [ 34,  62,  80],
#         [ 34,  62,  80],
#         [ 34,  62,  80]],
#
#        [[ 12,  31,  44],
#         [ 12,  31,  44],
#         [ 12,  31,  44],
#         ...,
#         [ 34,  62,  80],
#         [ 34,  62,  80],
#         [ 34,  62,  80]],
#
#        [[ 12,  30,  45],
#         [ 12,  30,  45],
#         [ 12,  30,  45],
#         ...,
#         [ 32,  60,  78],
#         [ 32,  60,  78],
#         [ 32,  60,  78]],
#
#        ...,
#
#        [[  0,  24,  34],
#         [  0,  24,  34],
#         [  0,  24,  34],
#         ...,
#         [ 89,  95, 119],
#         [ 90,  93, 118],
#         [ 89,  93, 117]],
#
#        [[  0,  24,  34],
#         [  0,  24,  34],
#         [  0,  23,  33],
#         ...,
#         [ 91,  96, 120],
#         [ 93,  96, 121],
#         [ 94,  96, 121]],
#
#        [[  2,  24,  34],
#         [  2,  24,  34],
#         [  1,  23,  33],
# ...

# %%
cv2.imshow('My Image',img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
img_plt = plt.imread("D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\Dog1.png")

# %%
type(img_plt)
# Out:
# numpy.ndarray

# %%
img_plt.shape
# Out:
# (675, 1200, 4)

# %%
plt.imshow(img_plt)

# %% [markdown]
# ### Scikit

# %%
from skimage import io

# %%
img_sk =io.imread("D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\Dog1.png")

# %%
type(img_sk)
# Out:
# numpy.ndarray

# %%
img_sk.shape
# Out:
# (675, 1200, 4)

# %%
io.imshow(img_sk)
# Out:
# C:\Users\PGCP-AI\AppData\Local\Temp\ipykernel_13732\2086481906.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_sk)

# %% [markdown]
# ## Python Imaging Library

# %%
from PIL import Image

# %%
img_pil = Image.open("D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\Dog1.png")

# %%
type(img_pil)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img_pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x675>

# %% [markdown]
# ## Tensor Flow

# %%
import tensorflow as tf

# %%
img_tf = tf.io.read_file("D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\Dog1.png")
img_tf = tf.io.decode_image(img_tf)

# %%
plt.imshow(img_tf)

# %%
img_plt[0,0]
# Out:
# array([0.17254902, 0.12156863, 0.04705882, 1.        ], dtype=float32)

# %% [markdown]
# ## Grayscale  image

# %%
img_gray = cv2.imread("D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\Dog1.png",0)

# %%
img_gray.shape
# Out:
# (675, 1200)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap ="gray")

# %%
img_new = cv2.cvtColor(img_cv, cv2.COLOR_RGB2GRAY)

# %%
img_new.shape
# Out:
# (675, 1200)

# %%
plt.imshow(img_new, cmap="gray")

# %%
img_new.shape[0] * img_new.shape[1]
# Out:
# 810000

# %%
import numpy as np

# %%
imgz = np.zeros([500,500], dtype =np.uint8)

# %%
imgz.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(imgz, cmap="gray")

# %%
imgz[250,:]=255
imgz[:,250]=255

# %%
plt.imshow(imgz, cmap="gray")

# %%
imgz[:100,:100]=255

# %%
plt.imshow(imgz, cmap="gray")

# %%
for i in range(100,251):
    imgz[i,i]=255
plt.imshow(imgz, cmap="gray")

# %%
sample_img = np.zeros([1000000], dtype=np.uint8)

# %%
for i in range(1000000):
    sample_img[i] = np.random.randint(0,255)

# %%
sample_img = sample_img.reshape(1000,1000)

# %%
plt.imshow(sample_img, cmap="gray")

# %%
chess=np.zeros([8,8])
for i in range(8):
    for j in range(8):
        if (i+j)%2==0:
            chess[i,j]=1
plt.imshow(chess, cmap="gray")

# %%
img_plt[0,0]
# Out:
# array([0.17254902, 0.12156863, 0.04705882, 1.        ], dtype=float32)

# %%
# Orange-255,165,0
#Green-0,255,0
# White-255,255,255

# %%
flag=np.zeros([300,400,3], dtype=np.uint8)

# %%
flag[:100,:]=[255,165,0]
flag[100:200,:]=[255,255,255]
flag[200:,:]=[0,128,0]
plt.imshow(flag)

# %% [markdown]
# # Day10

# %%
logo=plt.imread("D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\CDAC_LOGO.png")

# %%
logo.shape
# Out:
# (956, 1838, 4)

# %%
plt.imshow(logo)

# %%
img_dog=plt.imread("D:\\AshleshaRuchika\\PGCP-AI\\NLP\\images\\dog.jpg")
plt.imshow(img_dog)

# %%
r=img_dog[:,:,0]
r
# Out:
# array([[166, 166, 167, ..., 163, 162, 161],
#        [166, 166, 167, ..., 163, 163, 162],
#        [166, 167, 167, ..., 164, 164, 163],
#        ...,
#        [101, 100, 101, ..., 121, 119, 118],
#        [100,  99,  98, ..., 120, 120, 120],
#        [ 99,  99,  99, ..., 119, 120, 121]], shape=(400, 401), dtype=uint8)

# %%
g= img_dog[:,:,1]
b= img_dog[:,:,2]

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,3,1)
plt.imshow(r,cmap="gray")
plt.subplot(1,3,2)
plt.imshow(g,cmap="gray")
plt.subplot(1,3,3)
plt.imshow(b,cmap="gray")

# %%
# plt.imshow(img_cv[:,:,0])

# %%
r.shape,g.shape,b.shape
# Out:
# ((400, 401), (400, 401), (400, 401))

# %%
img_avg=(r+g+b)//3

# %%
plt.imshow(img_avg,cmap='gray')

# %%
r,g,b=cv2.split(img_dog)

# %%
r.shape,g.shape,b.shape
# Out:
# ((400, 401), (400, 401), (400, 401))

# %%
img_new=cv2.merge([b,g,r])

# %%
plt.imshow(img_new)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img_dog)
plt.subplot(1,2,2)
plt.imshow(img_new)

# %%
#convert BGR to RGB
img_rgb=cv2.cvtColor(img_new,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %% [markdown]
# # Image normalization

# %%
img_norm=img_dog/255

# %%
plt.imshow(img_norm)

# %%
img_norm
# Out:
# array([[[0.65098039, 0.7372549 , 0.48235294],
#         [0.65098039, 0.7372549 , 0.48235294],
#         [0.65490196, 0.74117647, 0.48627451],
#         ...,
#         [0.63921569, 0.72156863, 0.45882353],
#         [0.63529412, 0.71764706, 0.45490196],
#         [0.63137255, 0.71372549, 0.45098039]],
#
#        [[0.65098039, 0.7372549 , 0.48235294],
#         [0.65098039, 0.7372549 , 0.48235294],
#         [0.65490196, 0.74117647, 0.48627451],
#         ...,
#         [0.63921569, 0.72156863, 0.45882353],
#         [0.63921569, 0.72156863, 0.45882353],
#         [0.63529412, 0.71764706, 0.45490196]],
#
#        [[0.65098039, 0.7372549 , 0.48235294],
#         [0.65490196, 0.74117647, 0.48627451],
#         [0.65490196, 0.74117647, 0.48627451],
#         ...,
#         [0.64313725, 0.7254902 , 0.4627451 ],
#         [0.64313725, 0.7254902 , 0.4627451 ],
#         [0.63921569, 0.72156863, 0.45882353]],
#
#        ...,
#
#        [[0.39607843, 0.48235294, 0.23921569],
# ...

# %%
img_dog
# Out:
# array([[[166, 188, 123],
#         [166, 188, 123],
#         [167, 189, 124],
#         ...,
#         [163, 184, 117],
#         [162, 183, 116],
#         [161, 182, 115]],
#
#        [[166, 188, 123],
#         [166, 188, 123],
#         [167, 189, 124],
#         ...,
#         [163, 184, 117],
#         [163, 184, 117],
#         [162, 183, 116]],
#
#        [[166, 188, 123],
#         [167, 189, 124],
#         [167, 189, 124],
#         ...,
#         [164, 185, 118],
#         [164, 185, 118],
#         [163, 184, 117]],
#
#        ...,
#
#        [[101, 123,  61],
#         [100, 122,  60],
#         [101, 123,  61],
#         ...,
#         [121, 124,  69],
#         [119, 122,  67],
#         [118, 121,  66]],
#
#        [[100, 122,  58],
#         [ 99, 121,  57],
#         [ 98, 120,  58],
#         ...,
#         [120, 128,  71],
#         [120, 125,  69],
#         [120, 125,  71]],
#
#        [[ 99, 121,  56],
#         [ 99, 121,  56],
#         [ 99, 121,  59],
# ...

# %%
img_norm.dtype
# Out:
# dtype('float64')

# %%
img_dog.dtype
# Out:
# dtype('uint8')

# %%
img_new.dtype
# Out:
# dtype('uint8')

# %%
img_sk.dtype
# Out:
# dtype('uint8')

# %%
img_tf.dtype
# Out:
# tf.uint8

# %%
plt.imshow(img_dog)
