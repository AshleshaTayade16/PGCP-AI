# %%
pip install goslate
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for goslate: filename=goslate-1.5.4-py3-none-any.whl size=11673 sha256=cc750a724053d8c5cd2d341e0ecc1d824e439eae999254263c5fa5b469e3d1eb
#   Stored in directory: c:\users\pgcp-ai\appdata\local\pip\cache\wheels\b6\48\7a\e7458e7a110a5525687dd17a52d3e42c157a8d22a2c4d5e840
# ...

# %%
from goslate import Goslate

# %%
trans = Goslate()

# %%
text = "Hello friends! How ar you? I will teach you Python Programming"

# %%
trans.translate(text =text, target_language="mr")
# Out:
# 'नमस्कार मित्रांनो! तुम्ही कसे आहात? मी तुम्हाला पायथन प्रोग्रामिंग शिकवतो'
