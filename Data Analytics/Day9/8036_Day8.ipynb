# %%
# Assignment-8
# Name: Ashlesha Tayade                         Name: Ruchika Gaikwad
# PRN: 260240128008                             PRN: 260240128036

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title.
x = [10, 20, 30, 40, 50]
y = [10, 20, 30, 40, 50]

plt.plot(x, y, label='Growth Trend', color='blue')

plt.title('Line')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()

# %%
# 2. Write a Python program to draw a line using given axis values with suitable
# label in the x axis , y axis and a title.
x = [1,2,3]
y = [2,4,1]

plt.plot(x, y, label='Growth Trend', color='green')
plt.title('Line')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()

# %%
# 3. Write a Python program to draw a line using given axis values taken from a
# text file, with suitable label in the x axis, y axis and a title.
# Test Data:
# test.txt
# 1 2
# 2 4
# 3 1
x, y = [], []
for line in open("test.txt"):
    values = line.split()
    x.append(float(values[0]))
    y.append(float(values[1]))

plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Graph')
plt.show()

# %%
# 4. Write a Python program to draw line charts of the financial data of Alphabet
# Inc. between October 3, 2016 to October 7, 2016.
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017

df = pd.read_csv('fdata.csv')

plt.plot(df['Date'], df['Open'], label='Open')
plt.plot(df['Date'], df['High'], label='High')
plt.plot(df['Date'], df['Low'], label='Low')
plt.plot(df['Date'], df['Close'], label='Close')

plt.title('Financial Data Analysis (Oct 2016)')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# 5. Write a Python program to plot two or more lines on same plot with suitable
# legends of each line.
x1 = [10, 20, 30]
y1 = [20, 40, 10]
x2 = [10, 20, 30]
y2 = [40, 10, 30]
plt.plot(x1, y1, label='line 1', color='blue', linewidth=1)
plt.plot(x2, y2, label='line 2', color='green', linewidth=1)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Two or more lines on same plot with suitable legends')
plt.xlim(10, 30)
plt.ylim(10, 40)
plt.legend()
plt.show()

# %%
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.
x1 = [10, 20, 30]
y1 = [20, 40, 10]
x2 = [10, 20, 30]
y2 = [40, 10, 30]
plt.plot(x1, y1, label='line 1', color='blue', linewidth=1)
plt.plot(x2, y2, label='line 2', color='red', linewidth=3)
plt.ylabel('y - axis')
plt.title('Two or more lines on same plot with suitable legends')
plt.xlim(10, 30)
plt.ylim(10, 40)
plt.legend()
plt.show()

# %%
# 7. Write a Python program to plot two or more lines with different styles.
x1 = [10, 20, 30]
y1 = [20, 40, 10]
x2 = [10, 20, 30]
y2 = [40, 10, 30]
plt.plot(x1, y1, linestyle=":",label='line 1', color='blue', linewidth=1)
plt.plot(x2, y2, linestyle=":",label='line 2', color='red', linewidth=4)
plt.ylabel('y - axis')
plt.title('Two or more lines on same plot with suitable legends')
plt.xlim(10, 30)
plt.ylim(10, 40)
plt.legend()
plt.show()

# %%
# 8. Write a Python program to plot two or more lines and set the line markers.
x = [1, 4, 5, 6, 7]
y = [2, 6, 3, 6, 3]
plt.plot(x, y, color='red', linestyle=':', linewidth=2,  marker='o', markerfacecolor='blue', markersize=10)
plt.xlim(1, 8)
plt.ylim(1, 8)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Display marker')
plt.show()

# %%
# 9. Write a Python program to display the current axis limits values and set new axis values.
# 1. Define data for a basic line
x = [0, 50]
y = [0, 150]
plt.plot(x, y)
print("Default X-axis limits:", plt.xlim())
print("Default Y-axis limits:", plt.ylim())
plt.xlim(0, 100)
plt.ylim(0, 200)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Draw a line.')
print("Updated X-axis limits:", plt.xlim())
print("Updated Y-axis limits:", plt.ylim())
plt.show()
# Out:
# Default X-axis limits: (np.float64(-2.5), np.float64(52.5))
# Default Y-axis limits: (np.float64(-7.5), np.float64(157.5))
# Updated X-axis limits: (np.float64(0.0), np.float64(100.0))
# Updated Y-axis limits: (np.float64(0.0), np.float64(200.0))

# %%
# 10. Write a Python program to plot quantities which have an x and y position.
x1 = [2, 3, 5, 6, 8]
y1 = [1, 5, 10, 18, 20]
x2 = [3, 4, 6, 7, 9]
y2 = [2, 6, 11, 20, 22]
plt.plot(x1, y1, 'b*', markersize=5) 
plt.plot(x2, y2, 'ro', markersize=5) 
plt.axis([0, 10, 0, 30])
plt.show()

# %%
# 11. Write a Python program to plot several lines with different format styles in
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'g--', t, t**2, 'bs', t, t**3, 'r^')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # 11. Write a Python program to plot several lines with different format styles in
# ----> 2 t = np.arange(0., 5., 0.2)
#       3 plt.plot(t, t, 'g--', t, t**2, 'bs', t, t**3, 'r^')
#       4 plt.show()
#
# NameError: name 'np' is not defined

# %%
# 12. Write a Python program to create multiple types of charts (a simple curve and plot some quantities) on a single set of axes.
dates = ['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07']
values = [772.5, 776.4, 776.5, 776.9, 775.1]
plt.plot(dates, values, color='red', linewidth=1)
plt.plot(dates, values, 'ro', markersize=4)
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.show()

# %%
# 13. Write a Python program to display the grid and draw line charts of the
# closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Customized the grid lines with linestyle -, width .5. and color blue.
dates = ['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07']
values = [772.56, 776.43, 776.47, 776.86, 775.08]
plt.plot(dates, values, color='red', marker='o', markersize=4, linewidth=1)
plt.grid(color='blue', linestyle='-', linewidth=0.5)
plt.title('Closing stock value of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.show()

# %%
# 14. Write a Python program to display the grid and draw line charts of the
# closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Customized the grid lines with rendering with a larger grid (major grid) and a
# smaller grid (minor grid).Turn on the grid but turn off ticks.
dates = ['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07']
values = [772.5, 776.4, 776.5, 776.9, 775.1]
fig, ax = plt.subplots()
ax.plot(dates, values, color='red', marker='o', linewidth=1)
ax.grid(which='major', color='red', linestyle='-', linewidth=0.5)
ax.minorticks_on()
ax.grid(which='minor', color='black', linestyle=':', linewidth=0.5)
ax.tick_params(axis='both', which='both', length=0)
plt.title('Closing stock value of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.show()

# %%
# 15. Write a Python program to create multiple plots.
import matplotlib.pyplot as plt
plt.subplot2grid((2, 3), (0, 0), colspan=3)
plt.xticks([]),
plt.yticks([]) ,
plt.subplot2grid((2, 3), (1, 0))
plt.xticks([]), 
plt.yticks([]),
plt.subplot2grid((2, 3), (1, 1))
plt.xticks([]), 
plt.yticks([]).
plt.subplot2grid((2, 3), (1, 2))
plt.xticks([]),
plt.yticks([]),
plt.tight_layout()
plt.show()
