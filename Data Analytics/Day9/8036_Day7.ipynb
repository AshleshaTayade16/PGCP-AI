# %%
# Assignment-7
# Name: Ashlesha Tayade                         Name: Ruchika Gaikwad
# PRN: 260240128008                             PRN: 260240128036

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Write a Pandas program to detect missing values of a given DataFrame.Display True or False.
df = pd.DataFrame({
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
})
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
missing_values_mask = df.isna()
print("Original DataFrame:")
print(df)
print("\nMissing values (True/False):")
print(missing_values_mask)
# Out:
# Original DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Missing values (True/False):
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %%
# 2. Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.
missing_columns = df.columns[df.isnull().any()].tolist()
missing_columns
# Out:
# ['ord_no', 'ord_date', 'salesman_id']

# %%
# 3. Write a Pandas program to count the number of missing values in each column of a given DataFrame.
missing_count = df.isnull().sum()
missing_count
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %%
# 4. Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.
df.fillna(0)
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       0.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26           0         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          0.0
# 4       0.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       0.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          0.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      0.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          0.0

# %%
# 5. Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.
cleaned_df = df.dropna()
cleaned_df
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %%
# 6. Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.
cleaned_df = df.dropna(axis=1)
cleaned_df
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %%
# 7. Write a Pandas program to drop the rows where all elements are missing in a givenaDataFrame.
df1 = pd.DataFrame({
    'ord_no': [np.nan, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [np.nan, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': [np.nan, '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [np.nan, 3001.0, 3001.0, 3003.0, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, 3001.0]
})
df1
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
cleaned_df = df1.dropna(how='all')
cleaned_df
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
# 8. Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.
filtered_df = df1[df1.isnull().sum(axis=1) >= 2]
filtered_df
# Out:
#    ord_no  purch_amt ord_date  customer_id
# 0     NaN        NaN      NaN          NaN

# %%
# 9. Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values.
df1.dropna(subset=['ord_no'])
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
# 10. Write a Pandas program to keep the valid entries of a given DataFrame.
df1.dropna()
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 3   70004.0     110.50  2012-08-17       3003.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
# 11. Write a Pandas program to calculate the total number of missing values in a DataFrame.
df1.isnull().sum().sum()
# Out:
# np.int64(9)

# %%
# 12. Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.
df1[['ord_no']].fillna(0)
# Out:
#      ord_no
# 0       0.0
# 1       0.0
# 2   70002.0
# 3   70004.0
# 4       0.0
# 5   70005.0
# 6       0.0
# 7   70010.0
# 8   70003.0
# 9   70012.0
# 10      0.0
# 11  70013.0

# %%
# 13. Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame.
df.ffill()
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1   70001.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26  2012-09-10         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003       5001.0
# 4   70004.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6   70005.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004       5001.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10  70012.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001       5003.0

# %%
# 14. Write a Pandas program to replace NaNs with median or mean of the specified columns in a given DataFrame.

df['purch_amt'].fillna(df['purch_amt'].mean()).reset_index()
# Out:
#     index  purch_amt
# 0       0     150.50
# 1       1     270.65
# 2       2      65.26
# 3       3     110.50
# 4       4     948.50
# 5       5    2400.60
# 6       6    5760.00
# 7       7    1983.43
# 8       8    2480.40
# 9       9     250.45
# 10     10      75.29
# 11     11    3045.60

# %%
# 15. Write a Pandas program to interpolate the missing values using the Linear
# Interpolation method in a given DataFrame.
# From Wikipedia, in mathematics, linear interpolation is a method of curve fitting
# using linear polynomials to construct new data points within the range of a
# discrete set of known data points.
df_interpolated = df.copy()
numeric_cols = df.select_dtypes(include=[np.number]).columns
df_interpolated[numeric_cols] = df[numeric_cols].interpolate(method='linear')

df_interpolated
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1   70001.5     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003       5001.5
# 4   70004.5     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6   70007.5    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004       5002.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10  70012.5      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001       5003.0

# %%
# 16. Write a Pandas program to count the number of missing values of a specified
# column in a given DataFrame.
missing_count=df['ord_no'].isna().sum()
missing_count
# Out:
# np.int64(4)

# %%
# 17. Write a Pandas program to count the missing values in a given DataFrame.
df.isna().sum().sum()
# Out:
# np.int64(8)

# %%
# 18. Write a Pandas program to find the Indexes of missing values in a given
# DataFrame.
np.where(df.isna())
# Out:
# (array([ 1,  2,  3,  4,  6,  7, 10, 11]), array([0, 2, 4, 0, 0, 4, 0, 4]))

# %%
# 19. Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.
df.fillna(df.mode().iloc[0])
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1   70001.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26  2012-09-10         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003       5001.0
# 4   70001.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6   70001.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004       5001.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10  70001.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001       5001.0

# %%
#20. Write a Pandas program to create a hitmap for more information about the distribution of missing values in a given DataFrame.
sns.heatmap(df.isna(), cmap='viridis', cbar=True, yticklabels=True,)

plt.title('Heatmap of Missing Values (NaNs) in DataFrame', fontsize=14)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Row Index', fontsize=12)
plt.xticks(rotation=45)
plt.grid(which="minor", color="w", linestyle='-', linewidth=3)
plt.show()
