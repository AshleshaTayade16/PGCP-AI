# %%
#linaer regerssion on salary datset
import pandas as pd
from sklearn.model_selection import train,test_split
from sklearn.model_selection import LinearRegression
from sklearn.metrics import  mean_absolute_error,mean_squared_error,r2_sco
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 #linaer regerssion on salary datset
#       2 import pandas as pd
# ----> 3 from sklearn.model_selection import train,test_split
#       4 from sklearn.model_selection import LinearRegression
#       5 from sklearn.metrics import  mean_absolute_error,mean_squared_error,r2_sco
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df=pd.read_csv("salary.csv")
print(df)
X=df[['YearsExperience']]
y=df[['Salary']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df=pd.read_csv("salary.csv")
#       2 print(df)
#       3 X=df[['YearsExperience']]
#
# NameError: name 'pd' is not defined

# %%
#step2: split data into trining and testing 
#pip install scikit-learn
# from sklearn.model_selection import train test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 #step2: split data into trining and testing
#       2 #pip install scikit-learn
#       3 # from sklearn.model_selection import train test_split
# ----> 4 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)
#
# NameError: name 'train_test_split' is not defined

# %%
#step3: fit sample tinaer regression to training data
model=LinearRegression()
model.fit(X_train,y_train)

# %%
#Step4: Make prediction
y_pred = model.predict(X_test)

# %%
#step5: visualize test set results
plt.scatter(X_test,y_test,color="red")
plt.plot(X_train,moswl.predict(X_train),color="blue")
plt.title("Salary vs Experience(Test set)")
plt.xlabel("years of Experience")
plt.ylabel("Salary")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 #step5: visualize test set results
# ----> 2 plt.scatter(X_test,y_test,color="red")
#       3 plt.plot(X_train,moswl.predict(X_train),color="blue")
#       4 plt.title("Salary vs Experience(Test set)")
#
# NameError: name 'plt' is not defined

# %%
#step6: Make new prediction
new_X_values_df=pd.DataFrame({'YearsExperience':[1,3,5,,8,12,15,20,25]})
new_y_pred=model.predict(new_X_values_df)
print("\nPrediction for new experience values(1,3,5,,8,12,15,20,25])\n",new_y_pred)

# %%
#step7:model evalution
