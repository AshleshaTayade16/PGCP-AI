# %%
# Assignment-6
# Name: Ashlesha Tayade                      Name: Ruchika Gaikwad
# PRN: 260240128008                          PRN: 260240128036

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Write a Python programming to display a bar chart of the popularity of
# programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
programmingLanguages=pd.Series(["Java", "Python", "PHP", "JavaScript", "C#", "C++"])
popularity=pd.Series([22.2, 17.6, 8.8, 8, 7.7, 6.7])
plt.bar(x=programmingLanguages, height=popularity, color="blue", edgecolor="black",zorder=3)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 2. Write a Python programming to display a horizontal bar chart of the
# popularity of programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
plt.barh(y=programmingLanguages, width=popularity, color="green", edgecolor="black",zorder=3)
plt.title("Popularity of Programming Languages")
plt.ylabel("Programming Languages")
plt.xlabel("popularity")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 3. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Use uniform color.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
plt.bar(x=programmingLanguages, height=popularity, color="skyblue", edgecolor="black",zorder=3)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.gca().invert_yaxis()
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 4. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Use different color for each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
bar_colors = ['red', 'black', 'green', 'blue', 'yellow', 'cyan']
plt.bar(x=programmingLanguages, height=popularity, color=bar_colors , edgecolor="black",zorder=3)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 5. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Attach a text label above each bar displaying its
# popularity (float value).
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
bars=plt.bar(x=programmingLanguages, height=popularity, color="blue", edgecolor="black",zorder=3)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.3, yval, ha='center', va='bottom')
plt.show()

# %%
# 6. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Make blue border to each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# The code snippet gives the output shown in the following screenshot:
plt.bar(x=programmingLanguages, height=popularity, color="skyblue", edgecolor="blue",zorder=3)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 7. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Specify the position of each bar plot.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# The code snippet gives the output shown in the following screenshot:
positions = [0, 2, 5, 7, 15, 20]
plt.bar(x=positions, height=popularity, color="blue", edgecolor="black",zorder=3)
plt.xticks(positions, programmingLanguages)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 8. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Select the width of each bar and their positions.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
positions = [0, 1, 3, 4, 6, 7]
widths = [0.1, 0.2, 0.5, 0.8, 0.2, 0.4]
plt.bar(x=positions, height=popularity, width=widths, color="blue", edgecolor="black",zorder=3)
plt.xticks(positions, programmingLanguages)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 9. Write a Python programming to display a bar chart of the popularity of
# programming Languages. Increase bottom margin.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
plt.bar(x=programmingLanguages, height=popularity, color="blue", edgecolor="black",zorder=3)
plt.title("Popularity of Programming Languages")
plt.xlabel("Programming Languages")
plt.ylabel("Popularity")
plt.subplots_adjust(bottom=0.3)
plt.xticks(rotation=90)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 10. Write a Python program to create bar plot of scores by group and gender.
# Use multiple X values on the same chart for men and women.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)
groups = 5
men_means = (22, 30, 35, 35, 26)
women_means = (25, 32, 30, 35, 29)
index = np.arange(groups)
width = 0.35

plt.bar(index, men_means, width, label='Men')
plt.bar(index + width, women_means, width, label='Women')
plt.title('Scores by Person')
plt.xlabel("Person")
plt.ylabel("Scores")
plt.xticks(index + width / 2, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend()
plt.show()

# %%
# 11. Write a Python program to create bar plot from a DataFrame.
# Sample Data Frame:
# a b c d e
# 2 4,8,5,7,6
# 4 2,3,4,2,6
# 6 4,7,4,7,8
# 8 2,6,4,8,6
# 10 2,4,3,3,2
data = {
    'a': [2, 4, 6, 8, 10],
    'b': [4, 2, 4, 2, 2],
    'c': [8, 3, 7, 6, 4],
    'd': [5, 4, 4, 4, 3],
    'e': [7, 2, 7, 8, 3],
    'f': [6, 6, 8, 6, 2]
}
df = pd.DataFrame(data, index=[2, 4, 6, 8, 10])

df.plot(kind='bar',zorder=3)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth=0.5, color='gray')
plt.grid(which='minor', linestyle='--', linewidth=0.5, color='lightgray', alpha=0.6)
plt.show()

# %%
# 12. Write a Python program to create bar plots with error bars on the same
# figure.
# Sample Date
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645
mean_velocity = (0.2474, 0.1235, 0.1737, 0.1824)
std_deviation = (0.3314, 0.2278, 0.2836, 0.2645)
n_groups = len(mean_velocity)
index = np.arange(n_groups)
bar_width = 0.35
plt.bar(index, mean_velocity, bar_width,alpha=0.8,color='red',edgecolor='black', yerr=std_deviation,error_kw={'ecolor': 'blue', 'linewidth': 1, 'capsize': 5}, label='Velocity')
plt.xlabel('Velocity')
plt.ylabel('Scores')
plt.title('Scores by Velocity')

plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# 13. Write a Python program to create bar plots with errorbars on the same
# figure. Attach a text label above each bar displaying men means (integer
# value).
# Sample Data
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645
display_means = [54, 42, 67, 58, 30]
display_std = [4, 3, 5, 1, 5] 
ind = np.arange(len(display_means)) 
width = 0.35       
fig, ax = plt.subplots()
bars = ax.bar(ind, display_means, width, color='r', yerr=display_std,edgecolor='black', ecolor='blue', capsize=3, label='Men')
ax.bar_label(bars, padding=3, fmt='%d')
ax.set_ylabel('Scores')
ax.set_xlabel('Velocity')
ax.set_title('Scores by Velocity')
ax.set_xticks(ind)
ax.set_ylim(0, 80) 
ax.legend()
plt.show()

# %%
# 14. Write a Python program to create a stacked bar plot with error bars.
# Note: Use bottom to stack the women?s bars on top of the men?s bars.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)
# Men Standard deviation = (4, 3, 4, 1, 5)
# Women Standard deviation = (3, 5, 2, 3, 3)
men_means = (22, 30, 35, 35, 26)
women_means = (25, 32, 30, 35, 29)
men_std = (4, 3, 4, 1, 5)
women_std = (3, 5, 2, 3, 3)
ind = np.arange(5)   
width = 0.35      
fig, ax = plt.subplots()
p1 = ax.bar(ind, men_means, width, yerr=men_std, color='red', edgecolor='black', ecolor='blue', capsize=2)
p2 = ax.bar(ind, women_means, width, bottom=men_means, yerr=women_std,  color='green', edgecolor='black', ecolor='green', capsize=2)
ax.set_ylabel('Scores')
ax.set_xlabel('Groups')
ax.set_title('Scores by group\nand gender')
ax.set_xticks(ind)
ax.set_xticklabels(('Group1', 'Group2', 'Group3', 'Group4', 'Group5'))
ax.set_ylim(0, 80)
ax.legend((p1[0], p2[0]), ('Men', 'Women'))
plt.show()

# %%
# 15. Write a Python program to create a horizontal bar chart with differently
# ordered colors.
# Note: Use bottom to stack the women?s bars on top of the men?s bars.
# Sample Data Set:
# languages = [['Language','Science','Math'],
# ['Science','Math','Language'],
# ['Math','Language','Science']]
# numbers = [{'Language':75, 'Science':88, 'Math':96},
# {'Language':71, 'Science':95, 'Math':92},
# {'Language':75, 'Science':90, 'Math':89}]
students = ['Student-1', 'Student-2', 'Student-3']
languages = [
    ['Language', 'Science', 'Math'],
    ['Science', 'Math', 'Language'],
    ['Math', 'Language', 'Science']
]
numbers = [
    {'Language': 75, 'Science': 88, 'Math': 96},
    {'Language': 71, 'Science': 95, 'Math': 92},
    {'Language': 75, 'Science': 90, 'Math': 89}
]
colors = {'Language': 'red', 'Math': 'green', 'Science': 'blue'}

fig, ax = plt.subplots()
for i, student in enumerate(students):
    current_left = 0
    
    for lang in languages[i]:
        score = numbers[i][lang]
        ax.barh(student, score, left=current_left, color=colors[lang], edgecolor='black')
        current_left += score
ax.set_xlabel('Scores')
ax.set_xticks([0, 50, 100, 150, 200, 250, 300])
ax.grid(True, which='both', linestyle='-', linewidth=0.5)
ax.set_axisbelow(True)
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor='red', label='Language'),
                   Patch(facecolor='green', label='Math'),
                   Patch(facecolor='blue', label='Science')]

ax.legend(handles=legend_elements, loc='upper right', bbox_to_anchor=(1.2, 1))
plt.tight_layout()
plt.show()

# %%
# 16. Write a Python program to create stack bar plot and add label to each
# section.
# Sample data:
# people = ('G1','G2','G3','G4','G5','G6','G7','G8')
# segments = 4
# # multi-dimensional data
# data = [[ 3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039,
# 7.1123587, 12.77792868, 3.44773477],
# [ 11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195,
# 6.79685302, 7.24578743, 3.69371847],
# [ 3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182,
# 4.63832778, 11.16849999, 8.56883433],
# [ 4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185,
# 10.97567589, 3.98287652, 8.80552122]]

people = ('G1','G2','G3','G4','G5','G6','G7','G8')
data = np.array([
    [3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039, 7.1123587, 12.77792868, 3.44773477],
    [11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195, 6.79685302, 7.24578743, 3.69371847],
    [3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182, 4.63832778, 11.16849999, 8.56883433],
    [4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185, 10.97567589, 3.98287652, 8.80552122]
])

colors = ['red', 'green', 'white', 'm']
y_pos = np.arange(len(people))
left = np.zeros(len(people)) 
fig, ax = plt.subplots(figsize=(10, 8))
for i in range(len(data)):
    widths = data[i]
    bars = ax.barh(y_pos, widths, left=left, color=colors[i], edgecolor='black')
    row_totals = data.sum(axis=0)
    for j, (rect, width) in enumerate(zip(bars, widths)):
        percent = int(100 * width / row_totals[j])
        x_pos = left[j] + width / 2
        ax.text(x_pos, rect.get_y() + rect.get_height()/2, f'{percent}%', 
                ha='center', va='center', color='black', fontsize=10)
    left += widths


ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.set_xlabel('Scores')
ax.set_xlim(0, 40)
plt.tight_layout()
plt.show()

# %%
# 17. Write a Python program to add textures (black and white) to bars and
# wedges.
# Note: Use bottom to stack the womens bars on top of the mens bars.
patterns = ('|', '\\', '//', '+', '-', '.', '*', 'x', 'o', 'O')
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
for i in range(len(patterns)):
    ax.bar(i, 3, color='white', edgecolor='black', hatch=patterns[i])
ax.set_xticks(range(0, 11, 2))
ax.set_yticks([0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0])
plt.xlim(-0.5, 10)
plt.ylim(0, 3)
plt.show()
