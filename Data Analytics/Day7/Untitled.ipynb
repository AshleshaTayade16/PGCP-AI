# %%
#Binomial distribution
from scipy.stats import binom

# %%
#Given values
n=5 #Total number of students
k=3   #Number of students who like Python
p=0.66   #Probablity that a student like Python


#CAlculate binomial probability
probability=binom.pmf(k,n,p)
print(f"The probability that exactly {k} out of {n} students like Python is: {probability:.4f}")
# Out:
# The probability that exactly 3 out of 5 students like Python is: 0.3323

# %%
#Hospital records show that of patients suffering from a specific disease,'75%' die of it. 
# What is the probability that of six randomly selected Patients, four will recover?

n=6
k=4
p=0.25

probability=binom.pmf(k,n,p)
print(f"The probability that exactly {k} out of {n} Patients will recover: {probability:.4f}")
# Out:
# The probability that exactly 4 out of 6 Patients will recover: 0.0330

# %%
# A(blindfolded) marksman finds that on the average, he hits the target'4' times out of '5'. If he fires '4' shots, what is a probability
# of (a) more than '2' hits and (b) at least '3' misses?

p=4/5
n=4
print(binom.pmf(k=3,n=n,p=p)+binom.pmf(k=4,n=n,p=p))
print(binom.pmf(k=0,n=n,p=p)+binom.pmf(k=1,n=n,p=p))
print(binom.cdf(k=1,n=n,p=p))
# Out:
# 0.8192000000000003
# 0.027199999999999974
# 0.027199999999999978

# %%
#Normally, 65% of all the students who appear for C-DAC entrance test clear it.
# 50 students from a coaching class have appeared for C-DAC March 2024 entrance test. What is the probability that none of them will clear it? What is the
# probability that more than 40 will clear it?

print(binom.pmf(k=0,n=50,p=0))
print(1-binom.cdf(k=40,n=50,p=0.65))
# Out:
# 1.0
# 0.00669792345591147

# %%
#Poisson Distribution
# A company finds that on an average its defective products rate is 8 products a day. Find the probability of 4 defective
# products in a day

from scipy.stats import poisson
mu=8 #lambda
x=4 #same as k in some examples
print(poisson.pmf(x,mu))
# Out:
# 0.057252288495362
